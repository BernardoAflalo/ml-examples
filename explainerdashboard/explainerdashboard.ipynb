# %%
# !pip install explainerdashboard
# Out:
# Requirement already satisfied: explainerdashboard in d:\softwares\anaconda3\lib\site-packages (0.3.8)
# Requirement already satisfied: jupyter-dash in d:\softwares\anaconda3\lib\site-packages (from explainerdashboard) (0.4.0)
# Requirement already satisfied: dtreeviz>=1.3 in d:\softwares\anaconda3\lib\site-packages (from explainerdashboard) (1.3.3)
# Requirement already satisfied: waitress in d:\softwares\anaconda3\lib\site-packages (from explainerdashboard) (2.0.0)
# Requirement already satisfied: numpy in d:\softwares\anaconda3\lib\site-packages (from explainerdashboard) (1.20.3)
# Requirement already satisfied: flask-simplelogin in d:\softwares\anaconda3\lib\site-packages (from explainerdashboard) (0.1.1)
# Requirement already satisfied: orjson in d:\softwares\anaconda3\lib\site-packages (from explainerdashboard) (3.6.7)
# Requirement already satisfied: joblib in c:\users\borba\appdata\roaming\python\python39\site-packages (from explainerdashboard) (1.0.1)
# Requirement already satisfied: dash-auth in d:\softwares\anaconda3\lib\site-packages (from explainerdashboard) (1.4.1)
# Requirement already satisfied: click in d:\softwares\anaconda3\lib\site-packages (from explainerdashboard) (8.0.3)
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'D:\Softwares\anaconda3\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: oyaml in d:\softwares\anaconda3\lib\site-packages (from explainerdashboard) (1.0)
# Requirement already satisfied: dash-bootstrap-components<1 in d:\softwares\anaconda3\lib\site-packages (from explainerdashboard) (0.13.1)
# Requirement already satisfied: shap>=0.37 in d:\softwares\anaconda3\lib\site-packages (from explainerdashboard) (0.40.0)
# Requirement already satisfied: dash>=2 in d:\softwares\anaconda3\lib\site-packages (from explainerdashboard) (2.1.0)
# Requirement already satisfied: pandas>=1.1 in d:\softwares\anaconda3\lib\site-packages (from explainerdashboard) (1.3.4)
# Requirement already satisfied: scikit-learn in d:\softwares\anaconda3\lib\site-packages (from explainerdashboard) (1.0.2)
# Requirement already satisfied: plotly>=5.0.0 in d:\softwares\anaconda3\lib\site-packages (from dash>=2->explainerdashboard) (5.5.0)
# Requirement already satisfied: Flask>=1.0.4 in d:\softwares\anaconda3\lib\site-packages (from dash>=2->explainerdashboard) (1.1.2)
# Requirement already satisfied: flask-compress in d:\softwares\anaconda3\lib\site-packages (from dash>=2->explainerdashboard) (1.10.1)
# Requirement already satisfied: dash-core-components==2.0.0 in d:\softwares\anaconda3\lib\site-packages (from dash>=2->explainerdashboard) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in d:\softwares\anaconda3\lib\site-packages (from dash>=2->explainerdashboard) (5.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in d:\softwares\anaconda3\lib\site-packages (from dash>=2->explainerdashboard) (2.0.0)
# Requirement already satisfied: pytest in d:\softwares\anaconda3\lib\site-packages (from dtreeviz>=1.3->explainerdashboard) (6.2.4)
# Requirement already satisfied: matplotlib in d:\softwares\anaconda3\lib\site-packages (from dtreeviz>=1.3->explainerdashboard) (3.4.3)
# Requirement already satisfied: colour in d:\softwares\anaconda3\lib\site-packages (from dtreeviz>=1.3->explainerdashboard) (0.1.5)
# Requirement already satisfied: graphviz>=0.9 in d:\softwares\anaconda3\lib\site-packages (from dtreeviz>=1.3->explainerdashboard) (0.19.1)
# Requirement already satisfied: pytz>=2017.3 in d:\softwares\anaconda3\lib\site-packages (from pandas>=1.1->explainerdashboard) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\softwares\anaconda3\lib\site-packages (from pandas>=1.1->explainerdashboard) (2.8.2)
# Requirement already satisfied: packaging>20.9 in d:\softwares\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (21.0)
# Requirement already satisfied: scipy in d:\softwares\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (1.7.1)
# Requirement already satisfied: cloudpickle in d:\softwares\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (2.0.0)
# Requirement already satisfied: numba in d:\softwares\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (0.54.1)
# Requirement already satisfied: slicer==0.0.7 in d:\softwares\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (0.0.7)
# Requirement already satisfied: tqdm>4.25.0 in d:\softwares\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (4.62.3)
# Requirement already satisfied: colorama in d:\softwares\anaconda3\lib\site-packages (from click->explainerdashboard) (0.4.4)
# Requirement already satisfied: flask-seasurf in d:\softwares\anaconda3\lib\site-packages (from dash-auth->explainerdashboard) (0.3.1)
# Requirement already satisfied: itsdangerous>=1.1.0 in d:\softwares\anaconda3\lib\site-packages (from dash-auth->explainerdashboard) (2.0.1)
# Requirement already satisfied: retrying in d:\softwares\anaconda3\lib\site-packages (from dash-auth->explainerdashboard) (1.3.3)
# Requirement already satisfied: ua-parser in d:\softwares\anaconda3\lib\site-packages (from dash-auth->explainerdashboard) (0.10.0)
# Requirement already satisfied: requests in d:\softwares\anaconda3\lib\site-packages (from dash-auth->explainerdashboard) (2.26.0)
# Requirement already satisfied: chart-studio>=1.0.0 in d:\softwares\anaconda3\lib\site-packages (from dash-auth->explainerdashboard) (1.1.0)
# Requirement already satisfied: Flask-WTF<0.16.0,>=0.15.1 in d:\softwares\anaconda3\lib\site-packages (from flask-simplelogin->explainerdashboard) (0.15.1)
# Requirement already satisfied: WTForms>=2.1 in d:\softwares\anaconda3\lib\site-packages (from flask-simplelogin->explainerdashboard) (3.0.1)
# Requirement already satisfied: ipykernel in d:\softwares\anaconda3\lib\site-packages (from jupyter-dash->explainerdashboard) (6.4.1)
# Requirement already satisfied: ipython in d:\softwares\anaconda3\lib\site-packages (from jupyter-dash->explainerdashboard) (7.29.0)
# Requirement already satisfied: ansi2html in d:\softwares\anaconda3\lib\site-packages (from jupyter-dash->explainerdashboard) (1.7.0)
# Requirement already satisfied: pyyaml in d:\softwares\anaconda3\lib\site-packages (from oyaml->explainerdashboard) (6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\softwares\anaconda3\lib\site-packages (from scikit-learn->explainerdashboard) (2.2.0)
# Requirement already satisfied: six in d:\softwares\anaconda3\lib\site-packages (from chart-studio>=1.0.0->dash-auth->explainerdashboard) (1.16.0)
# Requirement already satisfied: Jinja2>=2.10.1 in d:\softwares\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2->explainerdashboard) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in d:\softwares\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2->explainerdashboard) (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\softwares\anaconda3\lib\site-packages (from packaging>20.9->shap>=0.37->explainerdashboard) (3.0.4)
# Requirement already satisfied: tenacity>=6.2.0 in d:\softwares\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=2->explainerdashboard) (8.0.1)
# Requirement already satisfied: MarkupSafe in d:\softwares\anaconda3\lib\site-packages (from WTForms>=2.1->flask-simplelogin->explainerdashboard) (2.0.1)
# Requirement already satisfied: brotli in d:\softwares\anaconda3\lib\site-packages (from flask-compress->dash>=2->explainerdashboard) (1.0.9)
# Requirement already satisfied: ipython-genutils in d:\softwares\anaconda3\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (0.2.0)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in d:\softwares\anaconda3\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (5.1.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in d:\softwares\anaconda3\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in d:\softwares\anaconda3\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (6.1.12)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in d:\softwares\anaconda3\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in d:\softwares\anaconda3\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (1.4.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\softwares\anaconda3\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (3.0.20)
# Requirement already satisfied: pygments in d:\softwares\anaconda3\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (2.10.0)
# Requirement already satisfied: jedi>=0.16 in d:\softwares\anaconda3\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (0.18.0)
# Requirement already satisfied: decorator in d:\softwares\anaconda3\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (5.1.0)
# Requirement already satisfied: backcall in d:\softwares\anaconda3\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in d:\softwares\anaconda3\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (58.0.4)
# Requirement already satisfied: pickleshare in d:\softwares\anaconda3\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (0.7.5)
# Requirement already satisfied: pillow>=6.2.0 in d:\softwares\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in d:\softwares\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\softwares\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (1.3.1)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in d:\softwares\anaconda3\lib\site-packages (from numba->shap>=0.37->explainerdashboard) (0.37.0)
# Requirement already satisfied: attrs>=19.2.0 in d:\softwares\anaconda3\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (21.2.0)
# Requirement already satisfied: iniconfig in d:\softwares\anaconda3\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (1.1.1)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in d:\softwares\anaconda3\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in d:\softwares\anaconda3\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (1.10.0)
# Requirement already satisfied: toml in d:\softwares\anaconda3\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (0.10.2)
# Requirement already satisfied: atomicwrites>=1.0 in d:\softwares\anaconda3\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (1.4.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\softwares\anaconda3\lib\site-packages (from requests->dash-auth->explainerdashboard) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\softwares\anaconda3\lib\site-packages (from requests->dash-auth->explainerdashboard) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\softwares\anaconda3\lib\site-packages (from requests->dash-auth->explainerdashboard) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in d:\softwares\anaconda3\lib\site-packages (from requests->dash-auth->explainerdashboard) (3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\softwares\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash->explainerdashboard) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in d:\softwares\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash->explainerdashboard) (4.8.1)
# Requirement already satisfied: pyzmq>=13 in d:\softwares\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash->explainerdashboard) (22.2.1)
# Requirement already satisfied: wcwidth in d:\softwares\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash->explainerdashboard) (0.2.5)
# Requirement already satisfied: pywin32>=1.0 in d:\softwares\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter-dash->explainerdashboard) (228)

# %%
from sklearn.ensemble import RandomForestClassifier
from google.colab.output import eval_js
from explainerdashboard import ClassifierExplainer, ExplainerDashboard
from explainerdashboard.datasets import titanic_survive

X_train, y_train, X_test, y_test = titanic_survive()
X_train.head
# Out:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
# <bound method NDFrame.head of                                              Fare    Age  PassengerClass  \
# Passenger
# Braund, Mr. Owen Harris                    7.2500   22.0               3
# Heikkinen, Miss. Laina                     7.9250   26.0               3
# Allen, Mr. William Henry                   8.0500   35.0               3
# Moran, Mr. James                           8.4583 -999.0               3
# McCarthy, Mr. Timothy J                   51.8625   54.0               1
# ...                                           ...    ...             ...
# Rice, Mrs. William (Margaret Norton)      29.1250   39.0               3
# Graham, Miss. Margaret Edith              30.0000   19.0               1
# Johnston, Miss. Catherine Helen "Carrie"  23.4500 -999.0               3
# Behr, Mr. Karl Howell                     30.0000   26.0               1
# Dooley, Mr. Patrick                        7.7500   32.0               3
#
#                                           No_of_siblings_plus_spouses_on_board  \
# Passenger
# Braund, Mr. Owen Harris                                                      1
# Heikkinen, Miss. Laina                                     0
# Allen, Mr. William Henry                                   0
# Moran, Mr. James                                           0
# McCarthy, Mr. Timothy J                                    0
# ...                                                      ...
# Rice, Mrs. William (Margaret Norton)                       0
# Graham, Miss. Margaret Edith                               0
# Johnston, Miss. Catherine Helen "Carrie"                   0
# Behr, Mr. Karl Howell                                      1
# Dooley, Mr. Patrick                                        0
#
#                                           Embarked_Queenstown  \
# Passenger
# Braund, Mr. Owen Harris                                     0
# Heikkinen, Miss. Laina                                      0
# Allen, Mr. William Henry                                    0
# Moran, Mr. James                                            1
# McCarthy, Mr. Timothy J                                     0
# ...                                                       ...
# Rice, Mrs. William (Margaret Norton)                        1
# Graham, Miss. Margaret Edith                                0
# Johnston, Miss. Catherine Helen "Carrie"                    0
# Behr, Mr. Karl Howell                                       0
# Dooley, Mr. Patrick                                         1
#
#                                           Embarked_Southampton  \
# Passenger
# Braund, Mr. Owen Harris                                      1
# Heikkinen, Miss. Laina                                       1
# Allen, Mr. William Henry                                     1
# Moran, Mr. James                                             0
# McCarthy, Mr. Timothy J                                      1
# ...                                                        ...
# Rice, Mrs. William (Margaret Norton)                         0
# Graham, Miss. Margaret Edith                                 1
# Johnston, Miss. Catherine Helen "Carrie"                     1
# Behr, Mr. Karl Howell                                        0
# Dooley, Mr. Patrick                                          0
#
#                                           Embarked_Unknown
# Passenger
# Braund, Mr. Owen Harris                                  0
# Heikkinen, Miss. Laina                                   0
# Allen, Mr. William Henry                                 0
# Moran, Mr. James                                         0
# McCarthy, Mr. Timothy J                                  0
# ...                                                    ...
# Rice, Mrs. William (Margaret Norton)                     0
# Graham, Miss. Margaret Edith                             0
# Johnston, Miss. Catherine Helen "Carrie"                 0
# Behr, Mr. Karl Howell                                    0
# Dooley, Mr. Patrick                                      0
#
# [691 rows x 21 columns]>

# %%
model = RandomForestClassifier(n_estimators=50, max_depth=5)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=50)

# %%
# What would be the host address?
print(eval_js("google.colab.kernel.proxyPort(8051)"))

# %%
explainer = ClassifierExplainer(
                model, X_test, y_test,
                # optional:
                cats=['Sex', 'Deck', 'Embarked'],
                labels=['Not survived', 'Survived'])

db = ExplainerDashboard(explainer, title="Titanic Explainer",
                    whatif=False, # you can switch off tabs with bools
                    shap_interaction=False,
                    decision_trees=False)
db.run(port=8051)
# Out:
# Detected RandomForestClassifier model: Changing class type to RandomForestClassifierExplainer...
# Note: model_output=='probability', so assuming that raw shap output of RandomForestClassifier is in probability space...
# Generating self.shap_explainer = shap.TreeExplainer(model)
# Building ExplainerDashboard..
# Detected notebook environment, consider setting mode='external', mode='inline' or mode='jupyterlab' to keep the notebook interactive while the dashboard is running...
# Generating layout...
# Calculating shap values...
# Calculating prediction probabilities...
# Calculating metrics...
# Calculating confusion matrices...
# Calculating classification_dfs...
# Calculating roc auc curves...
# Calculating pr auc curves...
# Calculating liftcurve_dfs...
# Calculating dependencies...
# Calculating permutation importances (if slow, try setting n_jobs parameter)...
# Calculating predictions...
# Calculating pred_percentiles...
# Reminder: you can store the explainer (including calculated dependencies) with explainer.dump('explainer.joblib') and reload with e.g. ClassifierExplainer.from_file('explainer.joblib')
# Registering callbacks...
# Starting ExplainerDashboard on http://192.168.0.168:8051
# Dash is running on http://0.0.0.0:8051/
#
#  * Serving Flask app "explainerdashboard.dashboards" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.0.168:8051/ (Press CTRL+C to quit)
# 192.168.0.168 - - [20/Mar/2022 15:33:14] "GET / HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:14] "GET /assets/bootstrap.min.css?m=1644969483.8404121 HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:14] "GET /_dash-component-suites/dash/deps/react@16.v2_1_0m1644969477.14.0.min.js HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:14] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_1_0m1644969477.14.0.min.js HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:14] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_1_0m1644969477.7.2.min.js HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:14] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_1_0m1644969477.12.1.min.js HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:14] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_1_0m1644969477.js HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:14] "GET /_dash-component-suites/dash/dash_table/bundle.v5_1_0m1644969477.js HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:14] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_1m1644969477.min.js HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:14] "GET /_dash-component-suites/dash_bootstrap_components/_components/dash_bootstrap_components.v0_13_1m1644969482.min.js HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:14] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_1_0m1644969477.js HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:14] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_1_0m1644969477.min.js HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:14] "GET /_dash-layout HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:14] "GET /_dash-dependencies HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:14] "GET /assets/favicon.ico?m=1644969483.8404121 HTTP/1.1" 304 -
# 192.168.0.168 - - [20/Mar/2022 15:33:14] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:14] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 204 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 204 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 204 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 204 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.168 - - [20/Mar/2022 15:33:16] "POST /_dash-update-component HTTP/1.1" 200 -
