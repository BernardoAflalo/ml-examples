# %%
# reference: https://www.youtube.com/watch?v=ZxXKISVkH6Y
import sys
import numpy as np
import math
import random

import gym
import gym_game

def simulate():
    global epsilon, epsilon_decay
    for episode in range(MAX_EPISODES):

        # Init environment
        state = env.reset()
        total_reward = 0

        # AI tries up to MAX_TRY times
        for t in range(MAX_TRY):

            # In the beginning, do random action to learn
            if random.uniform(0, 1) < epsilon:
                action = env.action_space.sample()
            else:
                action = np.argmax(q_table[state])

            # Do action and get result
            next_state, reward, done, _ = env.step(action)
            total_reward += reward

            # Get correspond q value from state, action pair
            q_value = q_table[state][action]
            best_q = np.max(q_table[next_state])

            # Q(state, action) <- (1 - a)Q(state, action) + a(reward + rmaxQ(next state, all actions))
            q_table[state][action] = (1 - learning_rate) * q_value + learning_rate * (reward + gamma * best_q)

            # Set up for the next iteration
            state = next_state

            # Draw games
            env.render()

            # When episode is done, print reward
            if done or t >= MAX_TRY - 1:
                print("Episode %d finished after %i time steps with total reward = %f." % (episode, t, total_reward))
                #print(q_table)
                break

        # exploring rate decay
        if epsilon >= 0.005:
            epsilon *= epsilon_decay



env = gym.make("Pygame-v0")
MAX_EPISODES = 999
MAX_TRY = 1000
epsilon = 0.5
epsilon_decay = 0.999
learning_rate = 0.1
gamma = 0.6
num_box = tuple((env.observation_space.high + np.ones(env.observation_space.shape)).astype(int))
q_table = np.zeros(num_box + (env.action_space.n,))
simulate()
# Out:
# Episode 0 finished after 25 time steps with total reward = -9804.500000.
# Episode 1 finished after 14 time steps with total reward = -9932.500000.
# Episode 2 finished after 17 time steps with total reward = -9857.500000.
# Episode 3 finished after 9 time steps with total reward = -9953.500000.
# Episode 4 finished after 61 time steps with total reward = -9429.500000.
# Episode 5 finished after 19 time steps with total reward = -9911.500000.
# Episode 6 finished after 53 time steps with total reward = -9551.500000.
# Episode 7 finished after 34 time steps with total reward = -9685.000000.
# Episode 8 finished after 21 time steps with total reward = -9824.000000.
# Episode 9 finished after 14 time steps with total reward = -9889.500000.
# Episode 10 finished after 18 time steps with total reward = -9865.500000.
# Episode 11 finished after 40 time steps with total reward = -9634.000000.
# Episode 12 finished after 41 time steps with total reward = -9649.000000.
# Episode 13 finished after 13 time steps with total reward = -9910.500000.
# Episode 14 finished after 54 time steps with total reward = -9516.500000.
# Episode 15 finished after 11 time steps with total reward = -9918.000000.
# Episode 16 finished after 38 time steps with total reward = -9644.500000.
# Episode 17 finished after 53 time steps with total reward = -9515.000000.
# Episode 18 finished after 23 time steps with total reward = -9824.500000.
# Episode 19 finished after 43 time steps with total reward = -9630.500000.
# Episode 20 finished after 60 time steps with total reward = -9435.000000.
# Episode 21 finished after 27 time steps with total reward = -9771.500000.
# Episode 22 finished after 20 time steps with total reward = -9842.000000.
# Episode 23 finished after 22 time steps with total reward = -9803.000000.
# Episode 24 finished after 21 time steps with total reward = -9829.500000.
# Episode 25 finished after 9 time steps with total reward = -9934.500000.
# Episode 26 finished after 19 time steps with total reward = -9867.500000.
# Episode 27 finished after 20 time steps with total reward = -9832.500000.
# Episode 28 finished after 64 time steps with total reward = -9433.000000.
# Episode 29 finished after 22 time steps with total reward = -9806.500000.
# Episode 30 finished after 15 time steps with total reward = -9895.500000.
# Episode 31 finished after 22 time steps with total reward = -9832.000000.
# Episode 32 finished after 60 time steps with total reward = -9465.500000.
# Episode 33 finished after 60 time steps with total reward = -9483.000000.
# Episode 34 finished after 70 time steps with total reward = -9429.500000.
# Episode 35 finished after 15 time steps with total reward = -9889.000000.
# Episode 36 finished after 12 time steps with total reward = -9912.000000.
# Episode 37 finished after 26 time steps with total reward = -9798.500000.
# Episode 38 finished after 21 time steps with total reward = -9830.500000.
# Episode 39 finished after 53 time steps with total reward = -9562.500000.
# Episode 40 finished after 52 time steps with total reward = -9535.500000.
# Episode 41 finished after 20 time steps with total reward = -9869.500000.
# Episode 42 finished after 24 time steps with total reward = -9798.000000.
# Episode 43 finished after 46 time steps with total reward = -9583.000000.
# Episode 44 finished after 62 time steps with total reward = -9456.000000.
# Episode 45 finished after 22 time steps with total reward = -9826.500000.
# Episode 46 finished after 23 time steps with total reward = -9834.500000.
# Episode 47 finished after 59 time steps with total reward = -9455.500000.
# Episode 48 finished after 12 time steps with total reward = -9911.000000.
# Episode 49 finished after 63 time steps with total reward = -9457.500000.
# Episode 50 finished after 11 time steps with total reward = -9921.000000.
# Episode 51 finished after 45 time steps with total reward = -9603.500000.
# Episode 52 finished after 49 time steps with total reward = -9548.500000.
# Episode 53 finished after 13 time steps with total reward = -9898.000000.
# Episode 54 finished after 10 time steps with total reward = -9928.500000.
# Episode 55 finished after 51 time steps with total reward = -9522.500000.
# Episode 56 finished after 39 time steps with total reward = -9660.000000.
# Episode 57 finished after 17 time steps with total reward = -9868.500000.
# Episode 58 finished after 14 time steps with total reward = -9913.000000.
# Episode 59 finished after 25 time steps with total reward = -9791.500000.
# Episode 60 finished after 31 time steps with total reward = -9719.500000.
# Episode 61 finished after 32 time steps with total reward = -9718.500000.
# Episode 62 finished after 23 time steps with total reward = -9814.500000.
# Episode 63 finished after 47 time steps with total reward = -9579.500000.
# Episode 64 finished after 13 time steps with total reward = -9902.000000.
# Episode 65 finished after 34 time steps with total reward = -9693.000000.
# Episode 66 finished after 54 time steps with total reward = -9498.500000.
# Episode 67 finished after 62 time steps with total reward = -9439.000000.
# Episode 68 finished after 54 time steps with total reward = -9491.500000.
# Episode 69 finished after 20 time steps with total reward = -9822.500000.
# Episode 70 finished after 20 time steps with total reward = -9845.000000.
# Episode 71 finished after 23 time steps with total reward = -9803.500000.
# Episode 72 finished after 52 time steps with total reward = -9554.500000.
# Episode 73 finished after 10 time steps with total reward = -9947.000000.
# Episode 74 finished after 17 time steps with total reward = -9864.000000.
# Episode 75 finished after 26 time steps with total reward = -9797.000000.
# Episode 76 finished after 13 time steps with total reward = -9909.500000.
# Episode 77 finished after 56 time steps with total reward = -9466.000000.
# Episode 78 finished after 56 time steps with total reward = -9493.500000.
# Episode 79 finished after 50 time steps with total reward = -9549.500000.
# Episode 80 finished after 28 time steps with total reward = -9741.500000.
# Episode 81 finished after 41 time steps with total reward = -9668.000000.
# Episode 82 finished after 13 time steps with total reward = -9904.000000.
# Episode 83 finished after 20 time steps with total reward = -9820.000000.
# Episode 84 finished after 50 time steps with total reward = -9535.500000.
# Episode 85 finished after 18 time steps with total reward = -9854.500000.
# Episode 86 finished after 55 time steps with total reward = -9491.000000.
# Episode 87 finished after 43 time steps with total reward = -9621.000000.
# Episode 88 finished after 36 time steps with total reward = -9768.000000.
# Episode 89 finished after 8 time steps with total reward = -9951.000000.
# Episode 90 finished after 25 time steps with total reward = -9792.000000.
# Episode 91 finished after 30 time steps with total reward = -9785.500000.
# Episode 92 finished after 7 time steps with total reward = -9983.000000.
# Episode 93 finished after 61 time steps with total reward = -9475.000000.
# Episode 94 finished after 47 time steps with total reward = -9605.000000.
# Episode 95 finished after 57 time steps with total reward = -9464.500000.
# Episode 96 finished after 54 time steps with total reward = -9522.000000.
# Episode 97 finished after 54 time steps with total reward = -9501.500000.
# Episode 98 finished after 20 time steps with total reward = -9847.500000.
# Episode 99 finished after 16 time steps with total reward = -9938.500000.
# Episode 100 finished after 20 time steps with total reward = -9861.500000.
# Episode 101 finished after 12 time steps with total reward = -9918.000000.
# Episode 102 finished after 15 time steps with total reward = -9886.500000.
# Episode 103 finished after 14 time steps with total reward = -9879.500000.
# Episode 104 finished after 60 time steps with total reward = -9442.500000.
# Episode 105 finished after 61 time steps with total reward = -9466.000000.
# Episode 106 finished after 58 time steps with total reward = -9455.500000.
# Episode 107 finished after 10 time steps with total reward = -9941.000000.
# Episode 108 finished after 52 time steps with total reward = -9552.000000.
# Episode 109 finished after 11 time steps with total reward = -9934.500000.
# Episode 110 finished after 30 time steps with total reward = -9723.500000.
# Episode 111 finished after 47 time steps with total reward = -9586.500000.
# Episode 112 finished after 17 time steps with total reward = -9855.500000.
# Episode 113 finished after 20 time steps with total reward = -9874.000000.
# Episode 114 finished after 20 time steps with total reward = -9862.500000.
# Episode 115 finished after 49 time steps with total reward = -9546.500000.
# Episode 116 finished after 51 time steps with total reward = -9534.500000.
# Episode 117 finished after 56 time steps with total reward = -9490.000000.
# Episode 118 finished after 47 time steps with total reward = -9601.000000.
# Episode 119 finished after 17 time steps with total reward = -9877.000000.
# Episode 120 finished after 19 time steps with total reward = -9901.000000.
# Episode 121 finished after 45 time steps with total reward = -9585.500000.
# Episode 122 finished after 44 time steps with total reward = -9614.500000.
# Episode 123 finished after 61 time steps with total reward = -9477.000000.
# Episode 124 finished after 61 time steps with total reward = -9428.500000.
# Episode 125 finished after 8 time steps with total reward = -9955.000000.
# Episode 126 finished after 16 time steps with total reward = -9880.500000.
# Episode 127 finished after 31 time steps with total reward = -9724.500000.
# Episode 128 finished after 17 time steps with total reward = -9854.000000.
# Episode 129 finished after 61 time steps with total reward = -9437.000000.
# Episode 130 finished after 10 time steps with total reward = -9931.500000.
# Episode 131 finished after 17 time steps with total reward = -9857.000000.
# Episode 132 finished after 23 time steps with total reward = -9798.500000.
# Episode 133 finished after 62 time steps with total reward = -9408.500000.
# Episode 134 finished after 10 time steps with total reward = -9935.000000.
# Episode 135 finished after 19 time steps with total reward = -9886.500000.
# Episode 136 finished after 13 time steps with total reward = -9903.500000.
# Episode 137 finished after 17 time steps with total reward = -9896.000000.
# Episode 138 finished after 30 time steps with total reward = -9741.500000.
# Episode 139 finished after 18 time steps with total reward = -9868.000000.
# Episode 140 finished after 18 time steps with total reward = -9844.500000.
# Episode 141 finished after 16 time steps with total reward = -9879.000000.
# Episode 142 finished after 12 time steps with total reward = -9948.000000.
# Episode 143 finished after 28 time steps with total reward = -9758.500000.
# Episode 144 finished after 18 time steps with total reward = -9875.000000.
# Episode 145 finished after 19 time steps with total reward = -9837.500000.
# Episode 146 finished after 63 time steps with total reward = -9460.500000.
# Episode 147 finished after 33 time steps with total reward = -9696.500000.
# Episode 148 finished after 15 time steps with total reward = -9912.500000.
# Episode 149 finished after 28 time steps with total reward = -9762.000000.
# Episode 150 finished after 13 time steps with total reward = -9929.500000.
# Episode 151 finished after 57 time steps with total reward = -9481.500000.
# Episode 152 finished after 60 time steps with total reward = -9462.000000.
# Episode 153 finished after 27 time steps with total reward = -9776.500000.
# Episode 154 finished after 35 time steps with total reward = -9674.500000.
# Episode 155 finished after 62 time steps with total reward = -9420.000000.
# Episode 156 finished after 10 time steps with total reward = -9959.000000.
# Episode 157 finished after 16 time steps with total reward = -9875.000000.
# Episode 158 finished after 63 time steps with total reward = -9441.500000.
# Episode 159 finished after 56 time steps with total reward = -9523.500000.
# Episode 160 finished after 20 time steps with total reward = -9840.500000.
# Episode 161 finished after 17 time steps with total reward = -9861.500000.
# Episode 162 finished after 59 time steps with total reward = -9447.500000.
# Episode 163 finished after 64 time steps with total reward = -9420.500000.
# Episode 164 finished after 29 time steps with total reward = -9757.000000.
# Episode 165 finished after 15 time steps with total reward = -9888.000000.
# Episode 166 finished after 56 time steps with total reward = -9493.000000.
# Episode 167 finished after 59 time steps with total reward = -9466.500000.
# Episode 168 finished after 59 time steps with total reward = -9477.500000.
# Episode 169 finished after 61 time steps with total reward = -9449.500000.
# Episode 170 finished after 17 time steps with total reward = -9894.500000.
# Episode 171 finished after 16 time steps with total reward = -9905.500000.
# Episode 172 finished after 61 time steps with total reward = -9443.500000.
# Episode 173 finished after 27 time steps with total reward = -9790.500000.
# Episode 174 finished after 31 time steps with total reward = -9720.500000.
# Episode 175 finished after 54 time steps with total reward = -9551.000000.
# Episode 176 finished after 27 time steps with total reward = -9752.500000.
# Episode 177 finished after 44 time steps with total reward = -9618.000000.
# Episode 178 finished after 18 time steps with total reward = -9845.500000.
# Episode 179 finished after 19 time steps with total reward = -9857.500000.
# Episode 180 finished after 65 time steps with total reward = -9395.500000.
# Episode 181 finished after 42 time steps with total reward = -9625.500000.
# Episode 182 finished after 55 time steps with total reward = -9489.500000.
# Episode 183 finished after 60 time steps with total reward = -9453.500000.
# Episode 184 finished after 16 time steps with total reward = -9898.500000.
# Episode 185 finished after 13 time steps with total reward = -9938.500000.
# Episode 186 finished after 31 time steps with total reward = -9735.000000.
# Episode 187 finished after 62 time steps with total reward = -9420.500000.
# Episode 188 finished after 31 time steps with total reward = -9720.500000.
# Episode 189 finished after 21 time steps with total reward = -9839.000000.
# Episode 190 finished after 30 time steps with total reward = -9742.000000.
# Episode 191 finished after 40 time steps with total reward = -9626.500000.
# Episode 192 finished after 54 time steps with total reward = -9532.500000.
# Episode 193 finished after 49 time steps with total reward = -9551.000000.
# Episode 194 finished after 19 time steps with total reward = -9832.500000.
# Episode 195 finished after 50 time steps with total reward = -9549.000000.
# Episode 196 finished after 25 time steps with total reward = -9780.000000.
# Episode 197 finished after 42 time steps with total reward = -9615.500000.
# Episode 198 finished after 23 time steps with total reward = -9816.500000.
# Episode 199 finished after 37 time steps with total reward = -9694.000000.
# Episode 200 finished after 21 time steps with total reward = -9859.000000.
# Episode 201 finished after 28 time steps with total reward = -9762.000000.
# Episode 202 finished after 17 time steps with total reward = -9883.500000.
# Episode 203 finished after 19 time steps with total reward = -9840.000000.
# Episode 204 finished after 60 time steps with total reward = -9438.500000.
# Episode 205 finished after 61 time steps with total reward = -9424.500000.
# Episode 206 finished after 45 time steps with total reward = -9587.000000.
# Episode 207 finished after 46 time steps with total reward = -9598.500000.
# Episode 208 finished after 9 time steps with total reward = -9957.500000.
# Episode 209 finished after 56 time steps with total reward = -9477.000000.
# Episode 210 finished after 12 time steps with total reward = -9907.000000.
# Episode 211 finished after 70 time steps with total reward = -9411.000000.
# Episode 212 finished after 52 time steps with total reward = -9513.500000.
# Episode 213 finished after 51 time steps with total reward = -9549.000000.
# Episode 214 finished after 60 time steps with total reward = -9456.500000.
# Episode 215 finished after 41 time steps with total reward = -9621.500000.
# Episode 216 finished after 25 time steps with total reward = -9792.500000.
# Episode 217 finished after 27 time steps with total reward = -9755.500000.
# Episode 218 finished after 13 time steps with total reward = -9901.500000.
# Episode 219 finished after 21 time steps with total reward = -9821.500000.
# Episode 220 finished after 63 time steps with total reward = -9424.000000.
# Episode 221 finished after 19 time steps with total reward = -9846.000000.
# Episode 222 finished after 33 time steps with total reward = -9703.500000.
# Episode 223 finished after 18 time steps with total reward = -9846.000000.
# Episode 224 finished after 12 time steps with total reward = -9921.500000.
# Episode 225 finished after 63 time steps with total reward = -9396.000000.
# Episode 226 finished after 61 time steps with total reward = -9433.000000.
# Episode 227 finished after 17 time steps with total reward = -9872.500000.
# Episode 228 finished after 41 time steps with total reward = -9625.000000.
# Episode 229 finished after 63 time steps with total reward = -9441.500000.
# Episode 230 finished after 46 time steps with total reward = -9566.500000.
# Episode 231 finished after 62 time steps with total reward = -9453.000000.
# Episode 232 finished after 63 time steps with total reward = -9421.000000.
# Episode 233 finished after 43 time steps with total reward = -9611.500000.
# Episode 234 finished after 46 time steps with total reward = -9568.500000.
# Episode 235 finished after 48 time steps with total reward = -9554.000000.
# Episode 236 finished after 60 time steps with total reward = -9450.500000.
# Episode 237 finished after 17 time steps with total reward = -9868.000000.
# Episode 238 finished after 61 time steps with total reward = -9458.000000.
# Episode 239 finished after 23 time steps with total reward = -9797.500000.
# Episode 240 finished after 23 time steps with total reward = -9839.500000.
# Episode 241 finished after 21 time steps with total reward = -9841.000000.
# Episode 242 finished after 17 time steps with total reward = -9874.000000.
# Episode 243 finished after 55 time steps with total reward = -9485.000000.
# Episode 244 finished after 46 time steps with total reward = -9587.000000.
# Episode 245 finished after 64 time steps with total reward = -9422.000000.
# Episode 246 finished after 21 time steps with total reward = -9850.000000.
# Episode 247 finished after 15 time steps with total reward = -9880.500000.
# Episode 248 finished after 45 time steps with total reward = -9615.000000.
# Episode 249 finished after 12 time steps with total reward = -9907.000000.
# Episode 250 finished after 14 time steps with total reward = -9909.500000.
# Episode 251 finished after 8 time steps with total reward = -9957.000000.
# Episode 252 finished after 58 time steps with total reward = -9446.500000.
# Episode 253 finished after 15 time steps with total reward = -9889.500000.
# Episode 254 finished after 13 time steps with total reward = -9925.500000.
# Episode 255 finished after 31 time steps with total reward = -9713.000000.
# Episode 256 finished after 43 time steps with total reward = -9609.500000.
# Episode 257 finished after 58 time steps with total reward = -9513.000000.
# Episode 258 finished after 22 time steps with total reward = -9839.500000.
# Episode 259 finished after 40 time steps with total reward = -9629.500000.
# Episode 260 finished after 20 time steps with total reward = -9821.000000.
# Episode 261 finished after 51 time steps with total reward = -9522.500000.
# Episode 262 finished after 26 time steps with total reward = -9809.000000.
# Episode 263 finished after 62 time steps with total reward = -9418.000000.
# Episode 264 finished after 62 time steps with total reward = -9421.500000.
# Episode 265 finished after 25 time steps with total reward = -9810.000000.
# Episode 266 finished after 53 time steps with total reward = -9512.500000.
# Episode 267 finished after 40 time steps with total reward = -9625.500000.
# Episode 268 finished after 61 time steps with total reward = -9451.000000.
# Episode 269 finished after 55 time steps with total reward = -9493.500000.
# Episode 270 finished after 62 time steps with total reward = -9430.000000.
# Episode 271 finished after 59 time steps with total reward = -9442.000000.
# Episode 272 finished after 53 time steps with total reward = -9521.000000.
# Episode 273 finished after 17 time steps with total reward = -9850.500000.
# Episode 274 finished after 14 time steps with total reward = -9892.000000.
# Episode 275 finished after 14 time steps with total reward = -9885.500000.
# Episode 276 finished after 58 time steps with total reward = -9469.000000.
# Episode 277 finished after 62 time steps with total reward = -9435.500000.
# Episode 278 finished after 23 time steps with total reward = -9795.500000.
# Episode 279 finished after 63 time steps with total reward = -9437.000000.
# Episode 280 finished after 16 time steps with total reward = -9874.500000.
# Episode 281 finished after 47 time steps with total reward = -9591.500000.
# Episode 282 finished after 33 time steps with total reward = -9714.500000.
# Episode 283 finished after 18 time steps with total reward = -9859.500000.
# Episode 284 finished after 33 time steps with total reward = -9719.500000.
# Episode 285 finished after 48 time steps with total reward = -9554.000000.
# Episode 286 finished after 51 time steps with total reward = -9524.000000.
# Episode 287 finished after 25 time steps with total reward = -9787.000000.
# Episode 288 finished after 32 time steps with total reward = -9704.000000.
# Episode 289 finished after 9 time steps with total reward = -9955.500000.
# Episode 290 finished after 56 time steps with total reward = -9472.000000.
# Episode 291 finished after 57 time steps with total reward = -9464.500000.
# Episode 292 finished after 61 time steps with total reward = -9439.000000.
# Episode 293 finished after 59 time steps with total reward = -9460.500000.
# Episode 294 finished after 16 time steps with total reward = -9866.000000.
# Episode 295 finished after 47 time steps with total reward = -9568.000000.
# Episode 296 finished after 26 time steps with total reward = -9765.000000.
# Episode 297 finished after 25 time steps with total reward = -9788.500000.
# Episode 298 finished after 32 time steps with total reward = -9724.000000.
# Episode 299 finished after 15 time steps with total reward = -9914.000000.
# Episode 300 finished after 63 time steps with total reward = -9412.000000.
# Episode 301 finished after 16 time steps with total reward = -9880.000000.
# Episode 302 finished after 19 time steps with total reward = -9843.500000.
# Episode 303 finished after 26 time steps with total reward = -9764.000000.
# Episode 304 finished after 67 time steps with total reward = -9409.000000.
# Episode 305 finished after 56 time steps with total reward = -9489.000000.
# Episode 306 finished after 63 time steps with total reward = -9458.500000.
# Episode 307 finished after 16 time steps with total reward = -9896.500000.
# Episode 308 finished after 52 time steps with total reward = -9558.000000.
# Episode 309 finished after 55 time steps with total reward = -9509.500000.
# Episode 310 finished after 62 time steps with total reward = -9403.000000.
# Episode 311 finished after 50 time steps with total reward = -9534.000000.
# Episode 312 finished after 39 time steps with total reward = -9637.000000.
# Episode 313 finished after 16 time steps with total reward = -9888.000000.
# Episode 314 finished after 45 time steps with total reward = -9586.500000.
# Episode 315 finished after 24 time steps with total reward = -9827.500000.
# Episode 316 finished after 18 time steps with total reward = -9876.500000.
# Episode 317 finished after 56 time steps with total reward = -9485.500000.
# Episode 318 finished after 34 time steps with total reward = -9691.500000.
# Episode 319 finished after 68 time steps with total reward = -9409.000000.
# Episode 320 finished after 40 time steps with total reward = -9651.000000.
# Episode 321 finished after 20 time steps with total reward = -9865.000000.
# Episode 322 finished after 26 time steps with total reward = -9814.000000.
# Episode 323 finished after 59 time steps with total reward = -9489.000000.
# Episode 324 finished after 62 time steps with total reward = -9420.000000.
# Episode 325 finished after 16 time steps with total reward = -9888.000000.
# Episode 326 finished after 15 time steps with total reward = -9882.000000.
# Episode 327 finished after 32 time steps with total reward = -9713.000000.
# Episode 328 finished after 28 time steps with total reward = -9761.000000.
# Episode 329 finished after 56 time steps with total reward = -9503.000000.
# Episode 330 finished after 49 time steps with total reward = -9543.000000.
# Episode 331 finished after 61 time steps with total reward = -9422.000000.
# Episode 332 finished after 39 time steps with total reward = -9643.500000.
# Episode 333 finished after 22 time steps with total reward = -9822.000000.
# Episode 334 finished after 19 time steps with total reward = -9904.000000.
# Episode 335 finished after 62 time steps with total reward = -9437.000000.
# Episode 336 finished after 46 time steps with total reward = -9572.000000.
# Episode 337 finished after 60 time steps with total reward = -9448.000000.
# Episode 338 finished after 16 time steps with total reward = -9874.500000.
# Episode 339 finished after 38 time steps with total reward = -9686.000000.
# Episode 340 finished after 15 time steps with total reward = -9901.500000.
# Episode 341 finished after 56 time steps with total reward = -9487.000000.
# Episode 342 finished after 20 time steps with total reward = -9832.000000.
# Episode 343 finished after 11 time steps with total reward = -9915.000000.
# Episode 344 finished after 45 time steps with total reward = -9594.000000.
# Episode 345 finished after 71 time steps with total reward = -9374.500000.
# Episode 346 finished after 57 time steps with total reward = -9486.500000.
# Episode 347 finished after 17 time steps with total reward = -9898.500000.
# Episode 348 finished after 40 time steps with total reward = -9622.500000.
# Episode 349 finished after 62 time steps with total reward = -9431.000000.
# Episode 350 finished after 41 time steps with total reward = -9619.000000.
# Episode 351 finished after 39 time steps with total reward = -9672.500000.
# Episode 352 finished after 17 time steps with total reward = -9853.500000.
# Episode 353 finished after 59 time steps with total reward = -9473.000000.
# Episode 354 finished after 26 time steps with total reward = -9776.000000.
# Episode 355 finished after 54 time steps with total reward = -9503.000000.
# Episode 356 finished after 61 time steps with total reward = -9438.000000.
# Episode 357 finished after 59 time steps with total reward = -9488.500000.
# Episode 358 finished after 22 time steps with total reward = -9799.500000.
# Episode 359 finished after 56 time steps with total reward = -9478.000000.
# Episode 360 finished after 64 time steps with total reward = -9436.000000.
# Episode 361 finished after 65 time steps with total reward = -9413.000000.
# Episode 362 finished after 26 time steps with total reward = -9782.000000.
# Episode 363 finished after 44 time steps with total reward = -9596.000000.
# Episode 364 finished after 63 time steps with total reward = -9449.500000.
# Episode 365 finished after 49 time steps with total reward = -9565.500000.
# Episode 366 finished after 39 time steps with total reward = -9650.000000.
# Episode 367 finished after 62 time steps with total reward = -9425.000000.
# Episode 368 finished after 57 time steps with total reward = -9466.000000.
# Episode 369 finished after 28 time steps with total reward = -9755.000000.
# Episode 370 finished after 55 time steps with total reward = -9482.000000.
# Episode 371 finished after 55 time steps with total reward = -9489.500000.
# Episode 372 finished after 61 time steps with total reward = -9450.500000.
# Episode 373 finished after 25 time steps with total reward = -9770.500000.
# Episode 374 finished after 68 time steps with total reward = -9381.000000.
# Episode 375 finished after 60 time steps with total reward = -9445.000000.
# Episode 376 finished after 63 time steps with total reward = -9417.000000.
# Episode 377 finished after 66 time steps with total reward = -9447.000000.
# Episode 378 finished after 55 time steps with total reward = -9499.000000.
# Episode 379 finished after 21 time steps with total reward = -9810.500000.
# Episode 380 finished after 25 time steps with total reward = -9782.000000.
# Episode 381 finished after 56 time steps with total reward = -9481.000000.
# Episode 382 finished after 65 time steps with total reward = -9449.000000.
# Episode 383 finished after 61 time steps with total reward = -9436.000000.
# Episode 384 finished after 21 time steps with total reward = -9836.000000.
# Episode 385 finished after 61 time steps with total reward = -9427.500000.
# Episode 386 finished after 22 time steps with total reward = -9823.000000.
# Episode 387 finished after 61 time steps with total reward = -9419.500000.
# Episode 388 finished after 72 time steps with total reward = -9353.000000.
# Episode 389 finished after 59 time steps with total reward = -9459.500000.
# Episode 390 finished after 16 time steps with total reward = -9886.000000.
# Episode 391 finished after 65 time steps with total reward = -9436.000000.
# Episode 392 finished after 51 time steps with total reward = -9526.000000.
# Episode 393 finished after 68 time steps with total reward = -9384.000000.
# Episode 394 finished after 50 time steps with total reward = -9536.000000.
# Episode 395 finished after 27 time steps with total reward = -9768.500000.
# Episode 396 finished after 61 time steps with total reward = -9456.500000.
# Episode 397 finished after 60 time steps with total reward = -9442.000000.
# Episode 398 finished after 59 time steps with total reward = -9466.500000.
# Episode 399 finished after 16 time steps with total reward = -9862.500000.
# Episode 400 finished after 16 time steps with total reward = -9876.000000.
# Episode 401 finished after 60 time steps with total reward = -9446.000000.
# Episode 402 finished after 57 time steps with total reward = -9472.000000.
# Episode 403 finished after 69 time steps with total reward = -9373.500000.
# Episode 404 finished after 56 time steps with total reward = -9483.000000.
# Episode 405 finished after 53 time steps with total reward = -9503.000000.
# Episode 406 finished after 20 time steps with total reward = -9829.000000.
# Episode 407 finished after 81 time steps with total reward = -9286.500000.
# Episode 408 finished after 27 time steps with total reward = -9762.000000.
# Episode 409 finished after 12 time steps with total reward = -9912.500000.
# Episode 410 finished after 122 time steps with total reward = -8914.000000.
# Episode 411 finished after 17 time steps with total reward = -9856.000000.
# Episode 412 finished after 29 time steps with total reward = -9738.000000.
# Episode 413 finished after 107 time steps with total reward = -8984.000000.
# Episode 414 finished after 8 time steps with total reward = -9957.000000.
# Episode 415 finished after 57 time steps with total reward = -9479.000000.
# Episode 416 finished after 76 time steps with total reward = -9356.000000.
# Episode 417 finished after 56 time steps with total reward = -9477.500000.
# Episode 418 finished after 30 time steps with total reward = -9756.500000.
# Episode 419 finished after 57 time steps with total reward = -9470.500000.
# Episode 420 finished after 96 time steps with total reward = -9197.000000.
# Episode 421 finished after 25 time steps with total reward = -9826.000000.
# Episode 422 finished after 33 time steps with total reward = -9695.500000.
# Episode 423 finished after 16 time steps with total reward = -9877.000000.
# Episode 424 finished after 17 time steps with total reward = -9855.500000.
# Episode 425 finished after 73 time steps with total reward = -9351.000000.
# Episode 426 finished after 61 time steps with total reward = -9438.000000.
# Episode 427 finished after 19 time steps with total reward = -9847.500000.
# Episode 428 finished after 86 time steps with total reward = -9228.000000.
# Episode 429 finished after 36 time steps with total reward = -9697.000000.
# Episode 430 finished after 21 time steps with total reward = -9857.500000.
# Episode 431 finished after 57 time steps with total reward = -9481.500000.
# Episode 432 finished after 18 time steps with total reward = -9859.000000.
# Episode 433 finished after 43 time steps with total reward = -9594.000000.
# Episode 434 finished after 52 time steps with total reward = -9525.500000.
# Episode 435 finished after 55 time steps with total reward = -9494.500000.
# Episode 436 finished after 62 time steps with total reward = -9458.000000.
# Episode 437 finished after 23 time steps with total reward = -9792.000000.
# Episode 438 finished after 98 time steps with total reward = -9197.500000.
# Episode 439 finished after 120 time steps with total reward = -8938.500000.
# Episode 440 finished after 38 time steps with total reward = -9641.000000.
# Episode 441 finished after 118 time steps with total reward = -8887.000000.
# Episode 442 finished after 61 time steps with total reward = -9439.000000.
# Episode 443 finished after 62 time steps with total reward = -9459.000000.
# Episode 444 finished after 14 time steps with total reward = -9921.500000.
# Episode 445 finished after 91 time steps with total reward = -9251.000000.
# Episode 446 finished after 67 time steps with total reward = -9405.500000.
# Episode 447 finished after 10 time steps with total reward = -9937.000000.
# Episode 448 finished after 13 time steps with total reward = -9909.000000.
# Episode 449 finished after 11 time steps with total reward = -9933.000000.
# Episode 450 finished after 65 time steps with total reward = -9422.000000.
# Episode 451 finished after 15 time steps with total reward = -9892.000000.
# Episode 452 finished after 61 time steps with total reward = -9417.500000.
# Episode 453 finished after 60 time steps with total reward = -9436.000000.
# Episode 454 finished after 122 time steps with total reward = -8924.000000.
# Episode 455 finished after 104 time steps with total reward = -9116.000000.
# Episode 456 finished after 60 time steps with total reward = -9446.000000.
# Episode 457 finished after 23 time steps with total reward = -9802.000000.
# Episode 458 finished after 28 time steps with total reward = -9747.500000.
# Episode 459 finished after 48 time steps with total reward = -9565.500000.
# Episode 460 finished after 73 time steps with total reward = -9338.000000.
# Episode 461 finished after 73 time steps with total reward = -9329.000000.
# Episode 462 finished after 26 time steps with total reward = -9762.500000.
# Episode 463 finished after 43 time steps with total reward = -9604.000000.
# Episode 464 finished after 51 time steps with total reward = -9527.500000.
# Episode 465 finished after 46 time steps with total reward = -9583.500000.
# Episode 466 finished after 11 time steps with total reward = -9937.000000.
# Episode 467 finished after 26 time steps with total reward = -9772.000000.
# Episode 468 finished after 25 time steps with total reward = -9798.000000.
# Episode 469 finished after 81 time steps with total reward = -9253.000000.
# Episode 470 finished after 53 time steps with total reward = -9505.000000.
# Episode 471 finished after 15 time steps with total reward = -9887.500000.
# Episode 472 finished after 69 time steps with total reward = -9364.000000.
# Episode 473 finished after 87 time steps with total reward = -9260.500000.
# Episode 474 finished after 118 time steps with total reward = -8904.500000.
# Episode 475 finished after 19 time steps with total reward = -9845.500000.
# Episode 476 finished after 11 time steps with total reward = -9915.000000.
# Episode 477 finished after 79 time steps with total reward = -9313.500000.
# Episode 478 finished after 58 time steps with total reward = -9468.500000.
# Episode 479 finished after 38 time steps with total reward = -9647.000000.
# Episode 480 finished after 69 time steps with total reward = -9368.500000.
# Episode 481 finished after 48 time steps with total reward = -9557.500000.
# Episode 482 finished after 16 time steps with total reward = -9889.500000.
# Episode 483 finished after 66 time steps with total reward = -9400.000000.
# Episode 484 finished after 57 time steps with total reward = -9482.500000.
# Episode 485 finished after 22 time steps with total reward = -9812.000000.
# Episode 486 finished after 60 time steps with total reward = -9453.500000.
# Episode 487 finished after 55 time steps with total reward = -9484.000000.
# Episode 488 finished after 18 time steps with total reward = -9846.500000.
# Episode 489 finished after 59 time steps with total reward = -9459.000000.
# Episode 490 finished after 28 time steps with total reward = -9776.000000.
# Episode 491 finished after 76 time steps with total reward = -9303.000000.
# Episode 492 finished after 23 time steps with total reward = -9832.000000.
# Episode 493 finished after 77 time steps with total reward = -9308.500000.
# Episode 494 finished after 62 time steps with total reward = -9439.500000.
# Episode 495 finished after 25 time steps with total reward = -9773.000000.
# Episode 496 finished after 43 time steps with total reward = -9600.500000.
# Episode 497 finished after 26 time steps with total reward = -9770.500000.
# Episode 498 finished after 58 time steps with total reward = -9477.000000.
# Episode 499 finished after 118 time steps with total reward = -8924.500000.
# Episode 500 finished after 74 time steps with total reward = -9329.000000.
# Episode 501 finished after 21 time steps with total reward = -9846.500000.
# Episode 502 finished after 23 time steps with total reward = -9813.000000.
# Episode 503 finished after 68 time steps with total reward = -9403.500000.
# Episode 504 finished after 11 time steps with total reward = -9912.500000.
# Episode 505 finished after 31 time steps with total reward = -9723.500000.
# Episode 506 finished after 61 time steps with total reward = -9414.500000.
# Episode 507 finished after 121 time steps with total reward = -8847.500000.
# Episode 508 finished after 54 time steps with total reward = -9510.000000.
# Episode 509 finished after 18 time steps with total reward = -9842.500000.
# Episode 510 finished after 60 time steps with total reward = -9437.500000.
# Episode 511 finished after 59 time steps with total reward = -9456.500000.
# Episode 512 finished after 58 time steps with total reward = -9459.000000.
# Episode 513 finished after 117 time steps with total reward = -8914.000000.
# Episode 514 finished after 50 time steps with total reward = -9546.500000.
# Episode 515 finished after 52 time steps with total reward = -9524.000000.
# Episode 516 finished after 100 time steps with total reward = -9127.000000.
# Episode 517 finished after 20 time steps with total reward = -9821.000000.
# Episode 518 finished after 85 time steps with total reward = -9211.500000.
# Episode 519 finished after 44 time steps with total reward = -9586.500000.
# Episode 520 finished after 60 time steps with total reward = -9447.500000.
# Episode 521 finished after 90 time steps with total reward = -9167.500000.
# Episode 522 finished after 77 time steps with total reward = -9303.500000.
# Episode 523 finished after 64 time steps with total reward = -9425.500000.
# Episode 524 finished after 66 time steps with total reward = -9394.000000.
# Episode 525 finished after 59 time steps with total reward = -9444.000000.
# Episode 526 finished after 26 time steps with total reward = -9761.500000.
# Episode 527 finished after 65 time steps with total reward = -9401.500000.
# Episode 528 finished after 91 time steps with total reward = -9167.500000.
# Episode 529 finished after 92 time steps with total reward = -9170.000000.
# Episode 530 finished after 37 time steps with total reward = -9667.000000.
# Episode 531 finished after 61 time steps with total reward = -9420.500000.
# Episode 532 finished after 21 time steps with total reward = -9871.500000.
# Episode 533 finished after 52 time steps with total reward = -9505.000000.
# Episode 534 finished after 87 time steps with total reward = -9226.500000.
# Episode 535 finished after 10 time steps with total reward = -9931.500000.
# Episode 536 finished after 62 time steps with total reward = -9421.000000.
# Episode 537 finished after 19 time steps with total reward = -9837.500000.
# Episode 538 finished after 16 time steps with total reward = -9865.500000.
# Episode 539 finished after 15 time steps with total reward = -9873.500000.
# Episode 540 finished after 44 time steps with total reward = -9588.000000.
# Episode 541 finished after 95 time steps with total reward = -9132.500000.
# Episode 542 finished after 44 time steps with total reward = -9587.000000.
# Episode 543 finished after 61 time steps with total reward = -9438.000000.
# Episode 544 finished after 59 time steps with total reward = -9436.500000.
# Episode 545 finished after 49 time steps with total reward = -9550.500000.
# Episode 546 finished after 46 time steps with total reward = -9600.000000.
# Episode 547 finished after 21 time steps with total reward = -9814.500000.
# Episode 548 finished after 77 time steps with total reward = -9299.000000.
# Episode 549 finished after 16 time steps with total reward = -9883.000000.
# Episode 550 finished after 50 time steps with total reward = -9538.000000.
# Episode 551 finished after 60 time steps with total reward = -9433.000000.
# Episode 552 finished after 66 time steps with total reward = -9387.000000.
# Episode 553 finished after 61 time steps with total reward = -9442.500000.
# Episode 554 finished after 69 time steps with total reward = -9409.000000.
# Episode 555 finished after 24 time steps with total reward = -9781.500000.
# Episode 556 finished after 116 time steps with total reward = -8909.500000.
# Episode 557 finished after 65 time steps with total reward = -9428.000000.
# Episode 558 finished after 42 time steps with total reward = -9607.000000.
# Episode 559 finished after 52 time steps with total reward = -9513.500000.
# Episode 560 finished after 61 time steps with total reward = -9432.500000.
# Episode 561 finished after 67 time steps with total reward = -9398.000000.
# Episode 562 finished after 55 time steps with total reward = -9478.500000.
# Episode 563 finished after 65 time steps with total reward = -9396.000000.
# Episode 564 finished after 60 time steps with total reward = -9434.000000.
# Episode 565 finished after 60 time steps with total reward = -9437.500000.
# Episode 566 finished after 24 time steps with total reward = -9791.000000.
# Episode 567 finished after 56 time steps with total reward = -9515.500000.
# Episode 568 finished after 58 time steps with total reward = -9455.000000.
# Episode 569 finished after 32 time steps with total reward = -9705.000000.
# Episode 570 finished after 68 time steps with total reward = -9392.000000.
# Episode 571 finished after 61 time steps with total reward = -9456.000000.
# Episode 572 finished after 63 time steps with total reward = -9421.000000.
# Episode 573 finished after 59 time steps with total reward = -9441.000000.
# Episode 574 finished after 53 time steps with total reward = -9524.500000.
# Episode 575 finished after 59 time steps with total reward = -9441.000000.
# Episode 576 finished after 18 time steps with total reward = -9873.500000.
# Episode 577 finished after 61 time steps with total reward = -9422.500000.
# Episode 578 finished after 52 time steps with total reward = -9509.000000.
# Episode 579 finished after 72 time steps with total reward = -9329.500000.
# Episode 580 finished after 63 time steps with total reward = -9422.500000.
# Episode 581 finished after 66 time steps with total reward = -9383.500000.
# Episode 582 finished after 57 time steps with total reward = -9476.000000.
# Episode 583 finished after 58 time steps with total reward = -9456.500000.
# Episode 584 finished after 38 time steps with total reward = -9672.000000.
# Episode 585 finished after 47 time steps with total reward = -9589.500000.
# Episode 586 finished after 56 time steps with total reward = -9484.000000.
# Episode 587 finished after 45 time steps with total reward = -9576.500000.
# Episode 588 finished after 76 time steps with total reward = -9310.500000.
# Episode 589 finished after 32 time steps with total reward = -9716.500000.
# Episode 590 finished after 24 time steps with total reward = -9802.000000.
# Episode 591 finished after 62 time steps with total reward = -9415.000000.
# Episode 592 finished after 16 time steps with total reward = -9860.500000.
# Episode 593 finished after 65 time steps with total reward = -9410.500000.
# Episode 594 finished after 71 time steps with total reward = -9359.000000.
# Episode 595 finished after 23 time steps with total reward = -9795.500000.
# Episode 596 finished after 52 time steps with total reward = -9516.000000.
# Episode 597 finished after 52 time steps with total reward = -9517.000000.
# Episode 598 finished after 76 time steps with total reward = -9311.000000.
# Episode 599 finished after 63 time steps with total reward = -9419.500000.
# Episode 600 finished after 57 time steps with total reward = -9464.500000.
# Episode 601 finished after 55 time steps with total reward = -9483.500000.
# Episode 602 finished after 10 time steps with total reward = -9929.000000.
# Episode 603 finished after 29 time steps with total reward = -9739.500000.
# Episode 604 finished after 22 time steps with total reward = -9803.500000.
# Episode 605 finished after 29 time steps with total reward = -9734.000000.
# Episode 606 finished after 57 time steps with total reward = -9487.000000.
# Episode 607 finished after 23 time steps with total reward = -9801.500000.
# Episode 608 finished after 21 time steps with total reward = -9812.500000.
# Episode 609 finished after 59 time steps with total reward = -9439.000000.
# Episode 610 finished after 117 time steps with total reward = -8908.000000.
# Episode 611 finished after 62 time steps with total reward = -9426.500000.
# Episode 612 finished after 29 time steps with total reward = -9739.500000.
# Episode 613 finished after 67 time steps with total reward = -9420.500000.
# Episode 614 finished after 10 time steps with total reward = -9936.500000.
# Episode 615 finished after 46 time steps with total reward = -9568.000000.
# Episode 616 finished after 58 time steps with total reward = -9464.500000.
# Episode 617 finished after 104 time steps with total reward = -9024.000000.
# Episode 618 finished after 77 time steps with total reward = -9288.500000.
# Episode 619 finished after 62 time steps with total reward = -9418.500000.
# Episode 620 finished after 67 time steps with total reward = -9406.000000.
# Episode 621 finished after 62 time steps with total reward = -9426.500000.
# Episode 622 finished after 14 time steps with total reward = -9903.500000.
# Episode 623 finished after 121 time steps with total reward = -8883.000000.
# Episode 624 finished after 21 time steps with total reward = -9834.500000.
# Episode 625 finished after 32 time steps with total reward = -9723.500000.
# Episode 626 finished after 48 time steps with total reward = -9555.500000.
# Episode 627 finished after 68 time steps with total reward = -9369.000000.
# Episode 628 finished after 62 time steps with total reward = -9416.500000.
# Episode 629 finished after 59 time steps with total reward = -9449.500000.
# Episode 630 finished after 56 time steps with total reward = -9486.500000.
# Episode 631 finished after 43 time steps with total reward = -9607.500000.
# Episode 632 finished after 120 time steps with total reward = -8916.500000.
# Episode 633 finished after 54 time steps with total reward = -9506.500000.
# Episode 634 finished after 20 time steps with total reward = -9822.000000.
# Episode 635 finished after 87 time steps with total reward = -9236.500000.
# Episode 636 finished after 62 time steps with total reward = -9419.500000.
# Episode 637 finished after 23 time steps with total reward = -9849.500000.
# Episode 638 finished after 65 time steps with total reward = -9403.000000.
# Episode 639 finished after 63 time steps with total reward = -9424.500000.
# Episode 640 finished after 75 time steps with total reward = -9319.000000.
# ...
# Episode 788 finished after 77 time steps with total reward = -9299.000000.
# Episode 789 finished after 122 time steps with total reward = -8849.500000.
# Episode 790 finished after 120 time steps with total reward = -8919.500000.
# Episode 791 finished after 141 time steps with total reward = -8683.500000.
# Episode 792 finished after 16 time steps with total reward = -9871.000000.
# Episode 793 finished after 118 time steps with total reward = -8900.000000.
# Episode 794 finished after 37 time steps with total reward = -9668.000000.
# Episode 795 finished after 119 time steps with total reward = -8905.500000.
# Episode 796 finished after 14 time steps with total reward = -9906.000000.
# Episode 797 finished after 90 time steps with total reward = -9215.500000.
# Episode 798 finished after 123 time steps with total reward = -8837.000000.
# Episode 799 finished after 120 time steps with total reward = -8928.500000.
# Episode 800 finished after 122 time steps with total reward = -8834.000000.
# Episode 801 finished after 124 time steps with total reward = -8883.500000.
# Episode 802 finished after 17 time steps with total reward = -9862.500000.
# Episode 803 finished after 80 time steps with total reward = -9318.000000.
# Episode 804 finished after 84 time steps with total reward = -9206.000000.
# Episode 805 finished after 64 time steps with total reward = -9400.500000.
# Episode 806 finished after 123 time steps with total reward = -8852.500000.
# Episode 807 finished after 118 time steps with total reward = -8895.500000.
# Episode 808 finished after 80 time steps with total reward = -9273.000000.
# Episode 809 finished after 231 time steps with total reward = -7806.000000.
# Episode 810 finished after 97 time steps with total reward = -9213.000000.
# Episode 811 finished after 143 time steps with total reward = -8662.500000.
# Episode 812 finished after 194 time steps with total reward = -8205.500000.
# Episode 813 finished after 191 time steps with total reward = -8248.500000.
# Episode 814 finished after 125 time steps with total reward = -8844.500000.
# Episode 815 finished after 117 time steps with total reward = -8911.000000.
# Episode 816 finished after 64 time steps with total reward = -9417.000000.
# Episode 817 finished after 123 time steps with total reward = -8895.500000.
# Episode 818 finished after 237 time steps with total reward = -7777.000000.
# Episode 819 finished after 231 time steps with total reward = -7806.500000.
# Episode 820 finished after 245 time steps with total reward = -7721.500000.
# Episode 821 finished after 29 time steps with total reward = -9749.000000.
# Episode 822 finished after 233 time steps with total reward = -7784.000000.
# Episode 823 finished after 239 time steps with total reward = -7750.000000.
# Episode 824 finished after 63 time steps with total reward = -9419.000000.
# Episode 825 finished after 112 time steps with total reward = -8935.000000.
# Episode 826 finished after 236 time steps with total reward = -7778.000000.
# Episode 827 finished after 122 time steps with total reward = -8890.000000.
# Episode 828 finished after 81 time steps with total reward = -9231.500000.
# Episode 829 finished after 117 time steps with total reward = -8905.500000.
# Episode 830 finished after 80 time steps with total reward = -9278.500000.
# Episode 831 finished after 130 time steps with total reward = -8803.500000.
# Episode 832 finished after 77 time steps with total reward = -9266.500000.
# Episode 833 finished after 42 time steps with total reward = -9608.000000.
# Episode 834 finished after 22 time steps with total reward = -9804.000000.
# Episode 835 finished after 79 time steps with total reward = -9268.000000.
# Episode 836 finished after 64 time steps with total reward = -9409.000000.
# Episode 837 finished after 232 time steps with total reward = -7851.000000.
# Episode 838 finished after 84 time steps with total reward = -9251.500000.
# Episode 839 finished after 262 time steps with total reward = -7654.500000.
# Episode 840 finished after 57 time steps with total reward = -9491.500000.
# Episode 841 finished after 75 time steps with total reward = -9294.000000.
# Episode 842 finished after 164 time steps with total reward = -8494.000000.
# Episode 843 finished after 246 time steps with total reward = -7738.500000.
# Episode 844 finished after 238 time steps with total reward = -7775.000000.
# Episode 845 finished after 237 time steps with total reward = -7795.500000.
# Episode 846 finished after 148 time steps with total reward = -8776.500000.
# Episode 847 finished after 236 time steps with total reward = -7826.500000.
# Episode 848 finished after 242 time steps with total reward = -7780.000000.
# Episode 849 finished after 154 time steps with total reward = -8541.500000.
# Episode 850 finished after 171 time steps with total reward = -8377.000000.
# Episode 851 finished after 129 time steps with total reward = -8812.000000.
# Episode 852 finished after 244 time steps with total reward = -7725.000000.
# Episode 853 finished after 113 time steps with total reward = -8942.000000.
# Episode 854 finished after 39 time steps with total reward = -9636.000000.
# Episode 855 finished after 239 time steps with total reward = -7780.000000.
# Episode 856 finished after 124 time steps with total reward = -8886.000000.
# Episode 857 finished after 161 time steps with total reward = -8497.000000.
# Episode 858 finished after 167 time steps with total reward = -8478.000000.
# Episode 859 finished after 119 time steps with total reward = -8900.500000.
# Episode 860 finished after 116 time steps with total reward = -8903.500000.
# Episode 861 finished after 85 time steps with total reward = -9262.500000.
# Episode 862 finished after 85 time steps with total reward = -9233.000000.
# Episode 863 finished after 121 time steps with total reward = -8904.500000.
# Episode 864 finished after 120 time steps with total reward = -8872.000000.
# Episode 865 finished after 129 time steps with total reward = -8873.000000.
# Episode 866 finished after 251 time steps with total reward = -7720.000000.
# Episode 867 finished after 116 time steps with total reward = -8906.500000.
# Episode 868 finished after 120 time steps with total reward = -8859.000000.
# Episode 869 finished after 69 time steps with total reward = -9349.000000.
# Episode 870 finished after 239 time steps with total reward = -7756.500000.
# Episode 871 finished after 112 time steps with total reward = -8941.500000.
# Episode 872 finished after 76 time steps with total reward = -9328.000000.
# Episode 873 finished after 66 time steps with total reward = -9395.500000.
# Episode 874 finished after 115 time steps with total reward = -8947.000000.
# Episode 875 finished after 98 time steps with total reward = -9102.000000.
# Episode 876 finished after 72 time steps with total reward = -9322.000000.
# Episode 877 finished after 23 time steps with total reward = -9793.000000.
# Episode 878 finished after 62 time steps with total reward = -9423.500000.
# Episode 879 finished after 241 time steps with total reward = -7760.500000.
# Episode 880 finished after 244 time steps with total reward = -7789.000000.
# Episode 881 finished after 224 time steps with total reward = -7913.500000.
# Episode 882 finished after 154 time steps with total reward = -8606.500000.
# Episode 883 finished after 82 time steps with total reward = -9264.000000.
# Episode 884 finished after 114 time steps with total reward = -8939.000000.
# Episode 885 finished after 240 time steps with total reward = -7754.000000.
# Episode 886 finished after 241 time steps with total reward = -7779.500000.
# Episode 887 finished after 79 time steps with total reward = -9255.500000.
# Episode 888 finished after 59 time steps with total reward = -9438.500000.
# Episode 889 finished after 18 time steps with total reward = -9862.000000.
# Episode 890 finished after 171 time steps with total reward = -8400.500000.
# Episode 891 finished after 254 time steps with total reward = -7720.500000.
# Episode 892 finished after 69 time steps with total reward = -9378.500000.
# Episode 893 finished after 246 time steps with total reward = -7715.500000.
# Episode 894 finished after 237 time steps with total reward = -7823.000000.
# Episode 895 finished after 19 time steps with total reward = -9854.500000.
# Episode 896 finished after 69 time steps with total reward = -9363.000000.
# Episode 897 finished after 113 time steps with total reward = -8942.000000.
# Episode 898 finished after 251 time steps with total reward = -7718.000000.
# Episode 899 finished after 243 time steps with total reward = -7723.000000.
# Episode 900 finished after 114 time steps with total reward = -8915.000000.
# Episode 901 finished after 63 time steps with total reward = -9423.000000.
# Episode 902 finished after 234 time steps with total reward = -7794.500000.
# Episode 903 finished after 18 time steps with total reward = -9857.000000.
# Episode 904 finished after 118 time steps with total reward = -8903.500000.
# Episode 905 finished after 126 time steps with total reward = -8885.000000.
# Episode 906 finished after 62 time steps with total reward = -9421.000000.
# Episode 907 finished after 61 time steps with total reward = -9422.000000.
# Episode 908 finished after 115 time steps with total reward = -8948.500000.
# Episode 909 finished after 251 time steps with total reward = -7737.000000.
# Episode 910 finished after 268 time steps with total reward = -7610.000000.
# Episode 911 finished after 78 time steps with total reward = -9293.000000.
# Episode 912 finished after 85 time steps with total reward = -9196.500000.
# Episode 913 finished after 234 time steps with total reward = -7833.500000.
# Episode 914 finished after 183 time steps with total reward = -8330.500000.
# Episode 915 finished after 148 time steps with total reward = -8801.500000.
# Episode 916 finished after 257 time steps with total reward = -7722.000000.
# Episode 917 finished after 16 time steps with total reward = -9871.000000.
# Episode 918 finished after 245 time steps with total reward = -7743.000000.
# Episode 919 finished after 147 time steps with total reward = -8644.000000.
# Episode 920 finished after 80 time steps with total reward = -9264.500000.
# Episode 921 finished after 119 time steps with total reward = -8895.000000.
# Episode 922 finished after 304 time steps with total reward = -7389.500000.
# Episode 923 finished after 260 time steps with total reward = -7699.500000.
# Episode 924 finished after 272 time steps with total reward = -7694.500000.
# Episode 925 finished after 153 time steps with total reward = -8609.500000.
# Episode 926 finished after 138 time steps with total reward = -8720.000000.
# Episode 927 finished after 29 time steps with total reward = -9741.000000.
# Episode 928 finished after 150 time steps with total reward = -8686.500000.
# Episode 929 finished after 266 time steps with total reward = -7688.000000.
# Episode 930 finished after 33 time steps with total reward = -9715.000000.
# Episode 931 finished after 248 time steps with total reward = -7712.000000.
# Episode 932 finished after 115 time steps with total reward = -8921.500000.
# Episode 933 finished after 126 time steps with total reward = -8824.500000.
# Episode 934 finished after 310 time steps with total reward = -7370.500000.
# Episode 935 finished after 237 time steps with total reward = -7795.000000.
# Episode 936 finished after 14 time steps with total reward = -9888.500000.
# Episode 937 finished after 235 time steps with total reward = -7792.500000.
# Episode 938 finished after 241 time steps with total reward = -7751.500000.
# Episode 939 finished after 82 time steps with total reward = -9231.000000.
# Episode 940 finished after 128 time steps with total reward = -8890.500000.
# Episode 941 finished after 62 time steps with total reward = -9420.000000.
# Episode 942 finished after 163 time steps with total reward = -8511.500000.
# Episode 943 finished after 160 time steps with total reward = -8509.500000.
# Episode 944 finished after 178 time steps with total reward = -8407.500000.
# Episode 945 finished after 90 time steps with total reward = -9150.500000.
# Episode 946 finished after 114 time steps with total reward = -8947.000000.
# Episode 947 finished after 121 time steps with total reward = -8889.000000.
# Episode 948 finished after 239 time steps with total reward = -7760.000000.
# Episode 949 finished after 142 time steps with total reward = -8647.000000.
# Episode 950 finished after 115 time steps with total reward = -8947.000000.
# Episode 951 finished after 89 time steps with total reward = -9158.000000.
# Episode 952 finished after 232 time steps with total reward = -7819.500000.
# Episode 953 finished after 308 time steps with total reward = -7262.500000.
# Episode 954 finished after 197 time steps with total reward = -8140.500000.
# Episode 955 finished after 236 time steps with total reward = -7775.000000.
# Episode 956 finished after 234 time steps with total reward = -7814.500000.
# Episode 957 finished after 327 time steps with total reward = -7239.500000.
# Episode 958 finished after 81 time steps with total reward = -9248.000000.
# Episode 959 finished after 122 time steps with total reward = -8837.000000.
# Episode 960 finished after 60 time steps with total reward = -9435.000000.
# Episode 961 finished after 244 time steps with total reward = -7767.000000.
# Episode 962 finished after 32 time steps with total reward = -9711.500000.
# Episode 963 finished after 249 time steps with total reward = -7761.500000.
# Episode 964 finished after 64 time steps with total reward = -9421.500000.
# Episode 965 finished after 226 time steps with total reward = -7834.000000.
# Episode 966 finished after 65 time steps with total reward = -9398.000000.
# Episode 967 finished after 37 time steps with total reward = -9684.500000.
# Episode 968 finished after 64 time steps with total reward = -9425.000000.
# Episode 969 finished after 246 time steps with total reward = -7751.000000.
# Episode 970 finished after 135 time steps with total reward = -8797.500000.
# Episode 971 finished after 123 time steps with total reward = -8838.500000.
# Episode 972 finished after 243 time steps with total reward = -7771.000000.
# Episode 973 finished after 61 time steps with total reward = -9428.500000.
# Episode 974 finished after 106 time steps with total reward = -9081.000000.
# Episode 975 finished after 241 time steps with total reward = -7768.000000.
# Episode 976 finished after 99 time steps with total reward = -9160.500000.
# Episode 977 finished after 68 time steps with total reward = -9426.500000.
# Episode 978 finished after 239 time steps with total reward = -7780.000000.
# Episode 979 finished after 167 time steps with total reward = -8456.500000.
# Episode 980 finished after 61 time steps with total reward = -9438.500000.
# Episode 981 finished after 246 time steps with total reward = -7781.500000.
# Episode 982 finished after 81 time steps with total reward = -9251.000000.
# Episode 983 finished after 68 time steps with total reward = -9409.500000.
# Episode 984 finished after 326 time steps with total reward = -7268.500000.
# Episode 985 finished after 125 time steps with total reward = -8832.500000.
# Episode 986 finished after 65 time steps with total reward = -9417.500000.
# Episode 987 finished after 126 time steps with total reward = -8809.000000.
# Episode 988 finished after 243 time steps with total reward = -7766.000000.
# Episode 989 finished after 67 time steps with total reward = -9384.000000.
# Episode 990 finished after 119 time steps with total reward = -8901.500000.
# Episode 991 finished after 130 time steps with total reward = -8839.000000.
# Episode 992 finished after 66 time steps with total reward = -9398.500000.
# Episode 993 finished after 63 time steps with total reward = -9422.500000.
# Episode 994 finished after 125 time steps with total reward = -8857.500000.
# Episode 995 finished after 118 time steps with total reward = -8943.000000.
# Episode 996 finished after 248 time steps with total reward = -7745.500000.
# Episode 997 finished after 273 time steps with total reward = -7580.000000.
# Episode 998 finished after 139 time steps with total reward = -8789.500000.

# %%
q_table.shape
# Out:
# (11, 11, 11, 11, 11, 3)
