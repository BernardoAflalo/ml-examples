# %%
# reference: https://www.youtube.com/watch?v=ZxXKISVkH6Y
import sys
import numpy as np
import math
import random

import gym
import gym_game

def simulate():
    global epsilon, epsilon_decay
    for episode in range(MAX_EPISODES):

        # Init environment
        state = env.reset()
        total_reward = 0

        # AI tries up to MAX_TRY times
        for t in range(MAX_TRY):

            # In the beginning, do random action to learn
            if random.uniform(0, 1) < epsilon:
                action = env.action_space.sample()
            else:
                action = np.argmax(q_table[state])

            # Do action and get result
            next_state, reward, done, _ = env.step(action)
            total_reward += reward

            # Get correspond q value from state, action pair
            q_value = q_table[state][action]
            best_q = np.max(q_table[next_state])

            # Q(state, action) <- (1 - a)Q(state, action) + a(reward + rmaxQ(next state, all actions))
            q_table[state][action] = (1 - learning_rate) * q_value + learning_rate * (reward + gamma * best_q)

            # Set up for the next iteration
            state = next_state

            # Draw games
            env.render()

            # When episode is done, print reward
            if done or t >= MAX_TRY - 1:
                print("Episode %d finished after %i time steps with total reward = %f." % (episode, t, total_reward))
                #print(q_table)
                break

        # exploring rate decay
        if epsilon >= 0.005:
            epsilon *= epsilon_decay



env = gym.make("Pygame-v0")
MAX_EPISODES = 999
MAX_TRY = 1000
epsilon = 0.3
epsilon_decay = 0.999
learning_rate = 0.5
gamma = 0.6
num_box = tuple((env.observation_space.high + np.ones(env.observation_space.shape)).astype(int))
q_table = np.zeros(num_box + (env.action_space.n,))
simulate()
# Out:
# D:\data\github\ml-examples\car-q-learning\gym_game\envs\custom_env.py:11: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.observation_space = spaces.Box(np.array([0, 0, 0, 0, 0]), np.array([10, 10, 10, 10, 10]), dtype=np.int)
# Episode 0 finished after 44 time steps with total reward = -9620.500000.
# Episode 1 finished after 56 time steps with total reward = -9473.000000.
# Episode 2 finished after 28 time steps with total reward = -9740.000000.
# Episode 3 finished after 22 time steps with total reward = -9818.000000.
# Episode 4 finished after 19 time steps with total reward = -9856.000000.
# Episode 5 finished after 50 time steps with total reward = -9524.000000.
# Episode 6 finished after 54 time steps with total reward = -9487.000000.
# Episode 7 finished after 39 time steps with total reward = -9662.500000.
# Episode 8 finished after 17 time steps with total reward = -9854.500000.
# Episode 9 finished after 21 time steps with total reward = -9809.500000.
# Episode 10 finished after 34 time steps with total reward = -9682.500000.
# Episode 11 finished after 32 time steps with total reward = -9714.500000.
# Episode 12 finished after 10 time steps with total reward = -9928.500000.
# Episode 13 finished after 63 time steps with total reward = -9411.500000.
# Episode 14 finished after 34 time steps with total reward = -9688.000000.
# Episode 15 finished after 35 time steps with total reward = -9682.500000.
# Episode 16 finished after 11 time steps with total reward = -9923.000000.
# Episode 17 finished after 26 time steps with total reward = -9762.500000.
# Episode 18 finished after 62 time steps with total reward = -9436.500000.
# Episode 19 finished after 17 time steps with total reward = -9852.500000.
# Episode 20 finished after 38 time steps with total reward = -9649.500000.
# Episode 21 finished after 14 time steps with total reward = -9914.500000.
# Episode 22 finished after 36 time steps with total reward = -9662.000000.
# Episode 23 finished after 13 time steps with total reward = -9917.500000.
# Episode 24 finished after 18 time steps with total reward = -9887.000000.
# Episode 25 finished after 30 time steps with total reward = -9724.500000.
# Episode 26 finished after 27 time steps with total reward = -9755.500000.
# Episode 27 finished after 21 time steps with total reward = -9815.000000.
# Episode 28 finished after 30 time steps with total reward = -9734.000000.
# Episode 29 finished after 62 time steps with total reward = -9422.500000.
# Episode 30 finished after 52 time steps with total reward = -9502.500000.
# Episode 31 finished after 44 time steps with total reward = -9586.500000.
# Episode 32 finished after 55 time steps with total reward = -9472.000000.
# Episode 33 finished after 17 time steps with total reward = -9852.000000.
# Episode 34 finished after 59 time steps with total reward = -9438.000000.
# Episode 35 finished after 26 time steps with total reward = -9761.500000.
# Episode 36 finished after 12 time steps with total reward = -9921.000000.
# Episode 37 finished after 48 time steps with total reward = -9556.000000.
# Episode 38 finished after 14 time steps with total reward = -9881.000000.
# Episode 39 finished after 47 time steps with total reward = -9573.500000.
# Episode 40 finished after 23 time steps with total reward = -9811.000000.
# Episode 41 finished after 14 time steps with total reward = -9903.500000.
# Episode 42 finished after 39 time steps with total reward = -9648.000000.
# Episode 43 finished after 55 time steps with total reward = -9507.000000.
# Episode 44 finished after 16 time steps with total reward = -9870.000000.
# Episode 45 finished after 28 time steps with total reward = -9742.000000.
# Episode 46 finished after 54 time steps with total reward = -9493.000000.
# Episode 47 finished after 20 time steps with total reward = -9837.000000.
# Episode 48 finished after 30 time steps with total reward = -9734.500000.
# Episode 49 finished after 12 time steps with total reward = -9913.000000.
# Episode 50 finished after 56 time steps with total reward = -9473.500000.
# Episode 51 finished after 37 time steps with total reward = -9660.500000.
# Episode 52 finished after 45 time steps with total reward = -9585.000000.
# Episode 53 finished after 22 time steps with total reward = -9818.500000.
# Episode 54 finished after 54 time steps with total reward = -9485.000000.
# Episode 55 finished after 62 time steps with total reward = -9417.500000.
# Episode 56 finished after 59 time steps with total reward = -9491.000000.
# Episode 57 finished after 22 time steps with total reward = -9840.500000.
# Episode 58 finished after 51 time steps with total reward = -9557.500000.
# Episode 59 finished after 50 time steps with total reward = -9522.500000.
# Episode 60 finished after 42 time steps with total reward = -9609.000000.
# Episode 61 finished after 13 time steps with total reward = -9900.000000.
# Episode 62 finished after 50 time steps with total reward = -9548.500000.
# Episode 63 finished after 21 time steps with total reward = -9812.500000.
# Episode 64 finished after 24 time steps with total reward = -9790.500000.
# Episode 65 finished after 50 time steps with total reward = -9552.000000.
# Episode 66 finished after 16 time steps with total reward = -9868.500000.
# Episode 67 finished after 26 time steps with total reward = -9772.500000.
# Episode 68 finished after 50 time steps with total reward = -9526.500000.
# Episode 69 finished after 23 time steps with total reward = -9822.000000.
# Episode 70 finished after 54 time steps with total reward = -9491.000000.
# Episode 71 finished after 32 time steps with total reward = -9703.000000.
# Episode 72 finished after 52 time steps with total reward = -9535.000000.
# Episode 73 finished after 51 time steps with total reward = -9524.000000.
# Episode 74 finished after 55 time steps with total reward = -9474.500000.
# Episode 75 finished after 21 time steps with total reward = -9816.000000.
# Episode 76 finished after 61 time steps with total reward = -9421.500000.
# Episode 77 finished after 57 time steps with total reward = -9461.000000.
# Episode 78 finished after 58 time steps with total reward = -9446.500000.
# Episode 79 finished after 41 time steps with total reward = -9624.000000.
# Episode 80 finished after 20 time steps with total reward = -9820.000000.
# Episode 81 finished after 58 time steps with total reward = -9457.000000.
# Episode 82 finished after 49 time steps with total reward = -9546.500000.
# Episode 83 finished after 57 time steps with total reward = -9493.500000.
# Episode 84 finished after 52 time steps with total reward = -9519.000000.
# Episode 85 finished after 16 time steps with total reward = -9869.500000.
# Episode 86 finished after 28 time steps with total reward = -9759.500000.
# Episode 87 finished after 43 time steps with total reward = -9608.500000.
# Episode 88 finished after 21 time steps with total reward = -9828.000000.
# Episode 89 finished after 55 time steps with total reward = -9496.000000.
# Episode 90 finished after 15 time steps with total reward = -9898.500000.
# Episode 91 finished after 15 time steps with total reward = -9902.000000.
# Episode 92 finished after 56 time steps with total reward = -9466.000000.
# Episode 93 finished after 17 time steps with total reward = -9877.500000.
# Episode 94 finished after 55 time steps with total reward = -9495.500000.
# Episode 95 finished after 63 time steps with total reward = -9415.000000.
# Episode 96 finished after 15 time steps with total reward = -9879.000000.
# Episode 97 finished after 19 time steps with total reward = -9832.500000.
# Episode 98 finished after 50 time steps with total reward = -9523.500000.
# Episode 99 finished after 11 time steps with total reward = -9933.000000.
# Episode 100 finished after 54 time steps with total reward = -9503.000000.
# Episode 101 finished after 61 time steps with total reward = -9427.000000.
# Episode 102 finished after 51 time steps with total reward = -9544.000000.
# Episode 103 finished after 24 time steps with total reward = -9786.000000.
# Episode 104 finished after 58 time steps with total reward = -9446.500000.
# Episode 105 finished after 66 time steps with total reward = -9420.000000.
# Episode 106 finished after 31 time steps with total reward = -9720.500000.
# Episode 107 finished after 55 time steps with total reward = -9492.000000.
# Episode 108 finished after 10 time steps with total reward = -9928.500000.
# Episode 109 finished after 26 time steps with total reward = -9765.000000.
# Episode 110 finished after 52 time steps with total reward = -9506.500000.
# Episode 111 finished after 32 time steps with total reward = -9711.000000.
# Episode 112 finished after 29 time steps with total reward = -9750.500000.
# Episode 113 finished after 23 time steps with total reward = -9795.000000.
# Episode 114 finished after 53 time steps with total reward = -9503.500000.
# Episode 115 finished after 50 time steps with total reward = -9541.500000.
# Episode 116 finished after 59 time steps with total reward = -9434.500000.
# Episode 117 finished after 54 time steps with total reward = -9484.000000.
# Episode 118 finished after 41 time steps with total reward = -9610.500000.
# Episode 119 finished after 60 time steps with total reward = -9426.000000.
# Episode 120 finished after 38 time steps with total reward = -9643.500000.
# Episode 121 finished after 10 time steps with total reward = -9937.000000.
# Episode 122 finished after 60 time steps with total reward = -9434.500000.
# Episode 123 finished after 53 time steps with total reward = -9533.000000.
# Episode 124 finished after 18 time steps with total reward = -9860.000000.
# Episode 125 finished after 56 time steps with total reward = -9468.500000.
# Episode 126 finished after 54 time steps with total reward = -9506.000000.
# Episode 127 finished after 58 time steps with total reward = -9444.500000.
# Episode 128 finished after 55 time steps with total reward = -9475.000000.
# Episode 129 finished after 53 time steps with total reward = -9500.000000.
# Episode 130 finished after 10 time steps with total reward = -9923.000000.
# Episode 131 finished after 55 time steps with total reward = -9482.500000.
# Episode 132 finished after 14 time steps with total reward = -9916.500000.
# Episode 133 finished after 17 time steps with total reward = -9863.500000.
# Episode 134 finished after 56 time steps with total reward = -9477.500000.
# Episode 135 finished after 52 time steps with total reward = -9522.500000.
# Episode 136 finished after 52 time steps with total reward = -9526.500000.
# Episode 137 finished after 47 time steps with total reward = -9556.000000.
# Episode 138 finished after 55 time steps with total reward = -9471.500000.
# Episode 139 finished after 59 time steps with total reward = -9448.000000.
# Episode 140 finished after 21 time steps with total reward = -9812.500000.
# Episode 141 finished after 25 time steps with total reward = -9818.000000.
# Episode 142 finished after 21 time steps with total reward = -9814.000000.
# Episode 143 finished after 51 time steps with total reward = -9527.000000.
# Episode 144 finished after 47 time steps with total reward = -9554.000000.
# Episode 145 finished after 48 time steps with total reward = -9572.000000.
# Episode 146 finished after 51 time steps with total reward = -9525.000000.
# Episode 147 finished after 58 time steps with total reward = -9454.500000.
# Episode 148 finished after 54 time steps with total reward = -9511.000000.
# Episode 149 finished after 18 time steps with total reward = -9842.500000.
# Episode 150 finished after 60 time steps with total reward = -9453.000000.
# Episode 151 finished after 55 time steps with total reward = -9478.000000.
# Episode 152 finished after 19 time steps with total reward = -9842.000000.
# Episode 153 finished after 27 time steps with total reward = -9751.500000.
# Episode 154 finished after 61 time steps with total reward = -9426.000000.
# Episode 155 finished after 28 time steps with total reward = -9741.000000.
# Episode 156 finished after 29 time steps with total reward = -9735.500000.
# Episode 157 finished after 65 time steps with total reward = -9402.500000.
# Episode 158 finished after 47 time steps with total reward = -9558.000000.
# Episode 159 finished after 53 time steps with total reward = -9505.000000.
# Episode 160 finished after 52 time steps with total reward = -9506.000000.
# Episode 161 finished after 25 time steps with total reward = -9778.500000.
# Episode 162 finished after 62 time steps with total reward = -9433.000000.
# Episode 163 finished after 51 time steps with total reward = -9514.500000.
# Episode 164 finished after 13 time steps with total reward = -9890.500000.
# Episode 165 finished after 61 time steps with total reward = -9428.500000.
# Episode 166 finished after 46 time steps with total reward = -9568.000000.
# Episode 167 finished after 53 time steps with total reward = -9494.000000.
# Episode 168 finished after 54 time steps with total reward = -9513.500000.
# Episode 169 finished after 58 time steps with total reward = -9481.500000.
# Episode 170 finished after 59 time steps with total reward = -9448.500000.
# Episode 171 finished after 56 time steps with total reward = -9468.000000.
# Episode 172 finished after 49 time steps with total reward = -9538.500000.
# Episode 173 finished after 20 time steps with total reward = -9821.500000.
# Episode 174 finished after 33 time steps with total reward = -9692.500000.
# Episode 175 finished after 62 time steps with total reward = -9404.500000.
# Episode 176 finished after 28 time steps with total reward = -9744.500000.
# Episode 177 finished after 58 time steps with total reward = -9450.500000.
# Episode 178 finished after 10 time steps with total reward = -9935.000000.
# Episode 179 finished after 60 time steps with total reward = -9438.000000.
# Episode 180 finished after 57 time steps with total reward = -9458.500000.
# Episode 181 finished after 60 time steps with total reward = -9451.000000.
# Episode 182 finished after 55 time steps with total reward = -9477.500000.
# Episode 183 finished after 58 time steps with total reward = -9449.500000.
# Episode 184 finished after 27 time steps with total reward = -9752.500000.
# Episode 185 finished after 61 time steps with total reward = -9437.500000.
# Episode 186 finished after 61 time steps with total reward = -9422.500000.
# Episode 187 finished after 58 time steps with total reward = -9446.500000.
# Episode 188 finished after 15 time steps with total reward = -9919.500000.
# Episode 189 finished after 39 time steps with total reward = -9631.500000.
# Episode 190 finished after 62 time steps with total reward = -9417.500000.
# Episode 191 finished after 57 time steps with total reward = -9474.500000.
# Episode 192 finished after 60 time steps with total reward = -9443.000000.
# Episode 193 finished after 59 time steps with total reward = -9448.500000.
# Episode 194 finished after 61 time steps with total reward = -9433.000000.
# Episode 195 finished after 60 time steps with total reward = -9434.500000.
# Episode 196 finished after 13 time steps with total reward = -9920.500000.
# Episode 197 finished after 63 time steps with total reward = -9405.500000.
# Episode 198 finished after 23 time steps with total reward = -9814.000000.
# Episode 199 finished after 68 time steps with total reward = -9380.500000.
# Episode 200 finished after 63 time steps with total reward = -9405.000000.
# Episode 201 finished after 58 time steps with total reward = -9467.500000.
# Episode 202 finished after 58 time steps with total reward = -9459.500000.
# Episode 203 finished after 63 time steps with total reward = -9404.000000.
# Episode 204 finished after 65 time steps with total reward = -9399.000000.
# Episode 205 finished after 55 time steps with total reward = -9474.500000.
# Episode 206 finished after 39 time steps with total reward = -9647.500000.
# Episode 207 finished after 69 time steps with total reward = -9409.000000.
# Episode 208 finished after 64 time steps with total reward = -9413.000000.
# Episode 209 finished after 64 time steps with total reward = -9413.000000.
# Episode 210 finished after 57 time steps with total reward = -9457.000000.
# Episode 211 finished after 44 time steps with total reward = -9582.500000.
# Episode 212 finished after 19 time steps with total reward = -9831.000000.
# Episode 213 finished after 18 time steps with total reward = -9845.000000.
# Episode 214 finished after 51 time steps with total reward = -9538.500000.
# Episode 215 finished after 56 time steps with total reward = -9474.500000.
# Episode 216 finished after 65 time steps with total reward = -9409.000000.
# Episode 217 finished after 53 time steps with total reward = -9536.000000.
# Episode 218 finished after 62 time steps with total reward = -9425.000000.
# Episode 219 finished after 66 time steps with total reward = -9414.500000.
# Episode 220 finished after 33 time steps with total reward = -9698.500000.
# Episode 221 finished after 55 time steps with total reward = -9490.000000.
# Episode 222 finished after 68 time steps with total reward = -9371.500000.
# Episode 223 finished after 47 time steps with total reward = -9572.500000.
# Episode 224 finished after 19 time steps with total reward = -9880.500000.
# Episode 225 finished after 66 time steps with total reward = -9406.000000.
# Episode 226 finished after 59 time steps with total reward = -9450.500000.
# Episode 227 finished after 22 time steps with total reward = -9800.500000.
# Episode 228 finished after 28 time steps with total reward = -9756.000000.
# Episode 229 finished after 19 time steps with total reward = -9846.000000.
# Episode 230 finished after 78 time steps with total reward = -9331.000000.
# Episode 231 finished after 49 time steps with total reward = -9537.000000.
# Episode 232 finished after 77 time steps with total reward = -9299.500000.
# Episode 233 finished after 63 time steps with total reward = -9411.500000.
# Episode 234 finished after 52 time steps with total reward = -9510.000000.
# Episode 235 finished after 55 time steps with total reward = -9481.500000.
# Episode 236 finished after 43 time steps with total reward = -9597.500000.
# Episode 237 finished after 30 time steps with total reward = -9736.000000.
# Episode 238 finished after 118 time steps with total reward = -8909.000000.
# Episode 239 finished after 60 time steps with total reward = -9440.500000.
# Episode 240 finished after 58 time steps with total reward = -9459.000000.
# Episode 241 finished after 73 time steps with total reward = -9330.000000.
# Episode 242 finished after 61 time steps with total reward = -9428.000000.
# Episode 243 finished after 62 time steps with total reward = -9422.000000.
# Episode 244 finished after 87 time steps with total reward = -9184.000000.
# Episode 245 finished after 64 time steps with total reward = -9420.500000.
# Episode 246 finished after 14 time steps with total reward = -9886.500000.
# Episode 247 finished after 19 time steps with total reward = -9836.500000.
# Episode 248 finished after 24 time steps with total reward = -9797.500000.
# Episode 249 finished after 109 time steps with total reward = -8969.500000.
# Episode 250 finished after 74 time steps with total reward = -9316.500000.
# Episode 251 finished after 61 time steps with total reward = -9451.000000.
# Episode 252 finished after 35 time steps with total reward = -9679.500000.
# Episode 253 finished after 82 time steps with total reward = -9255.500000.
# Episode 254 finished after 67 time steps with total reward = -9422.000000.
# Episode 255 finished after 116 time steps with total reward = -8923.000000.
# Episode 256 finished after 48 time steps with total reward = -9575.000000.
# Episode 257 finished after 29 time steps with total reward = -9745.000000.
# Episode 258 finished after 126 time steps with total reward = -8857.000000.
# Episode 259 finished after 107 time steps with total reward = -9056.000000.
# Episode 260 finished after 89 time steps with total reward = -9264.500000.
# Episode 261 finished after 78 time steps with total reward = -9315.000000.
# Episode 262 finished after 41 time steps with total reward = -9655.500000.
# Episode 263 finished after 38 time steps with total reward = -9647.500000.
# Episode 264 finished after 59 time steps with total reward = -9438.000000.
# Episode 265 finished after 46 time steps with total reward = -9563.000000.
# Episode 266 finished after 125 time steps with total reward = -8915.500000.
# Episode 267 finished after 76 time steps with total reward = -9315.000000.
# Episode 268 finished after 53 time steps with total reward = -9495.000000.
# Episode 269 finished after 124 time steps with total reward = -8877.500000.
# Episode 270 finished after 16 time steps with total reward = -9869.500000.
# Episode 271 finished after 119 time steps with total reward = -8921.500000.
# Episode 272 finished after 30 time steps with total reward = -9734.500000.
# Episode 273 finished after 44 time steps with total reward = -9590.000000.
# Episode 274 finished after 49 time steps with total reward = -9541.500000.
# Episode 275 finished after 94 time steps with total reward = -9116.500000.
# Episode 276 finished after 118 time steps with total reward = -8899.500000.
# Episode 277 finished after 114 time steps with total reward = -8933.500000.
# Episode 278 finished after 41 time steps with total reward = -9626.500000.
# Episode 279 finished after 116 time steps with total reward = -8968.500000.
# Episode 280 finished after 26 time steps with total reward = -9764.000000.
# Episode 281 finished after 85 time steps with total reward = -9265.500000.
# Episode 282 finished after 63 time steps with total reward = -9402.500000.
# Episode 283 finished after 63 time steps with total reward = -9412.500000.
# Episode 284 finished after 63 time steps with total reward = -9437.500000.
# Episode 285 finished after 62 time steps with total reward = -9437.500000.
# Episode 286 finished after 118 time steps with total reward = -8924.000000.
# Episode 287 finished after 56 time steps with total reward = -9489.500000.
# Episode 288 finished after 129 time steps with total reward = -8804.000000.
# Episode 289 finished after 124 time steps with total reward = -8835.500000.
# Episode 290 finished after 61 time steps with total reward = -9422.500000.
# Episode 291 finished after 23 time steps with total reward = -9800.000000.
# Episode 292 finished after 100 time steps with total reward = -9147.500000.
# Episode 293 finished after 139 time steps with total reward = -8808.500000.
# Episode 294 finished after 98 time steps with total reward = -9110.500000.
# Episode 295 finished after 24 time steps with total reward = -9781.000000.
# Episode 296 finished after 56 time steps with total reward = -9508.000000.
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Borba\AppData\Local\Temp/ipykernel_9024/787709636.py", line 65, in <module>
#     simulate()
#   File "C:\Users\Borba\AppData\Local\Temp/ipykernel_9024/787709636.py", line 42, in simulate
#     env.render()
#   File "D:\Softwares\anaconda3\lib\site-packages\gym\core.py", line 286, in render
#     return self.env.render(mode, **kwargs)
#   File "D:\Softwares\anaconda3\lib\site-packages\gym\core.py", line 286, in render
#     return self.env.render(mode, **kwargs)
#   File "D:\data\github\ml-examples\car-q-learning\gym_game\envs\custom_env.py", line 27, in render
#     self.pygame.view()
#   File "D:\data\github\ml-examples\car-q-learning\gym_game\envs\pygame_2d.py", line 202, in view
#     if self.mode == 1:
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "D:\Softwares\anaconda3\lib\inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "D:\Softwares\anaconda3\lib\inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "D:\Softwares\anaconda3\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "D:\Softwares\anaconda3\lib\inspect.py", line 752, in getmodule
#     f = getabsfile(module)
#   File "D:\Softwares\anaconda3\lib\inspect.py", line 721, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "D:\Softwares\anaconda3\lib\inspect.py", line 706, in getsourcefile
#     if os.path.exists(filename):
#   File "D:\Softwares\anaconda3\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Borba\AppData\Local\Temp/ipykernel_9024/787709636.py", line 65, in <module>
#     simulate()
#   File "C:\Users\Borba\AppData\Local\Temp/ipykernel_9024/787709636.py", line 42, in simulate
#     env.render()
#   File "D:\Softwares\anaconda3\lib\site-packages\gym\core.py", line 286, in render
#     return self.env.render(mode, **kwargs)
#   File "D:\Softwares\anaconda3\lib\site-packages\gym\core.py", line 286, in render
#     return self.env.render(mode, **kwargs)
#   File "D:\data\github\ml-examples\car-q-learning\gym_game\envs\custom_env.py", line 27, in render
#     self.pygame.view()
#   File "D:\data\github\ml-examples\car-q-learning\gym_game\envs\pygame_2d.py", line 202, in view
#     if self.mode == 1:
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2066, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "D:\Softwares\anaconda3\lib\inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "D:\Softwares\anaconda3\lib\inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "D:\Softwares\anaconda3\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "D:\Softwares\anaconda3\lib\inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "D:\Softwares\anaconda3\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp/ipykernel_9024/787709636.py in <module>
#      64 q_table = np.zeros(num_box + (env.action_space.n,))
# ---> 65 simulate()
#
# ~\AppData\Local\Temp/ipykernel_9024/787709636.py in simulate()
#      41             # Draw games
# ---> 42             env.render()
#      43
#
# D:\Softwares\anaconda3\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     285     def render(self, mode="human", **kwargs):
# --> 286         return self.env.render(mode, **kwargs)
#     287
#
# D:\Softwares\anaconda3\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     285     def render(self, mode="human", **kwargs):
# --> 286         return self.env.render(mode, **kwargs)
#     287
#
# D:\data\github\ml-examples\car-q-learning\gym_game\envs\custom_env.py in render(self, mode, close)
#      26     def render(self, mode="human", close=False):
# ---> 27         self.pygame.view()
#
# D:\data\github\ml-examples\car-q-learning\gym_game\envs\pygame_2d.py in view(self)
#     201
# --> 202         if self.mode == 1:
#     203             self.screen.fill((0, 0, 0))
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2063                         # in the engines. This should return a list of strings.
# -> 2064                         stb = value._render_traceback_()
#    2065                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3363                         asy = compare(code)
# -> 3364                     if (await self.run_code(code, result,  async_=asy)):
#    3365                         return True
#
#     [... skipping hidden 1 frame]
#
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2065                     except Exception:
# -> 2066                         stb = self.InteractiveTB.structured_traceback(etype,
#    2067                                             value, tb, tb_offset=tb_offset)
#
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2063                         # in the engines. This should return a list of strings.
# -> 2064                         stb = value._render_traceback_()
#    2065                     except Exception:
#
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\async_helpers.py in _pseudo_sync_runner(coro)
#      66     """
#      67     try:
# ---> 68         coro.send(None)
#      69     except StopIteration as exc:
#      70         return exc.value
#
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple)
#    3170                     interactivity = 'async'
#    3171
# -> 3172                 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3173                        interactivity=interactivity, compiler=compiler, result=result)
#    3174
#
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3381             if result:
#    3382                 result.error_before_exec = sys.exc_info()[1]
# -> 3383             self.showtraceback()
#    3384             return True
#    3385
#
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2064                         stb = value._render_traceback_()
#    2065                     except Exception:
# -> 2066                         stb = self.InteractiveTB.structured_traceback(etype,
#    2067                                             value, tb, tb_offset=tb_offset)
#    2068
#
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1140         chained_exc_ids = set()
#    1141         while evalue:
# -> 1142             formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#    1143                                                                      chained_exceptions_tb_offset)
#    1144             exception = self.get_parts_of_chained_exception(evalue)
#
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# D:\Softwares\anaconda3\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
env.action_space

# %%
q_table.shape
